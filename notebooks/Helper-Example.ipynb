# %%
from localgraphclustering import *
import helper

import numpy as np
import matplotlib.pyplot as plt

# %%
for graph in ["senate", "JohnsHopkins"]:
    g = helper.lgc_data(graph)
    ncpdata = ncp.Ncp().produce(g, "mqi")
    ncpdata.plot.scatter("input_cond", "output_cond")
    plt.xlabel("input conductance")
    plt.ylabel("output conductance")
    plt.show()
# Out:
# There are  1  connected components in the graph
# There are  24  connected components in the graph
# /usr/local/lib/python3.6/site-packages/localgraphclustering/graph_class_local.py:510: UserWarning: The graph has multiple (24) components, using the largest with 5157 / 5180 nodes
#   self.number_of_components, len(maxccnodes), self._num_vertices))
