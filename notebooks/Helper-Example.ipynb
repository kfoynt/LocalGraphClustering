# %%
from localgraphclustering import *
import helper

import numpy as np
import matplotlib.pyplot as plt

# %%
for graph in ["senate", "JohnsHopkins"]:
    g = helper.lgc_data(graph)
    ncpdata = NCPData(g).mqi()
    ncpdata.as_data_frame().plot.scatter("input_cond", "output_cond")
    plt.xlabel("input conductance")
    plt.ylabel("output conductance")
    plt.show()
# Out:
# There are  1  connected components in the graph
# There are  24  connected components in the graph
# /Users/mengliu/Library/Python/3.6/lib/python/site-packages/localgraphclustering/graph_class_local.py:364: UserWarning: The graph has multiple (24) components, using the largest with 5157 / 5180 nodes
#   self.number_of_components, len(maxccnodes), self._num_vertices))
