# %%
import sys,os

try:
    from localgraphclustering import *
except:
    # when the package is not installed, import the local version instead. 
    # the notebook must be placed in the original "notebooks/" folder
    sys.path.append("../")
    from localgraphclustering import *
import helper

import numpy as np
import matplotlib.pyplot as plt

# %%
for graph in ["senate", "JohnsHopkins"]:
    g = helper.lgc_data(graph)
    ncpdata = NCPData(g)
    ncpdata.mqi()
    ncpdata.as_data_frame().plot.scatter("input_cond", "output_cond")
    plt.xlabel("input conductance")
    plt.ylabel("output conductance")
    plt.show()
# Out:
# There are  1  connected components in the graph
# There are  24  connected components in the graph
# /usr/local/lib/python3.7/site-packages/localgraphclustering/GraphLocal.py:621: UserWarning:
#
# The graph has multiple (24) components, using the largest with 5157 / 5180 nodes
