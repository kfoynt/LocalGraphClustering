# %%
import scipy as sp
import numpy as np
import time

try:
    from localgraphclustering import *
except:
    # when the package is not installed, import the local version instead. 
    # the notebook must be placed in the original "notebooks/" folder
    sys.path.append("../")
    from localgraphclustering import * 

import time

import networkx as nx

import random

import statistics as stat_

# %% [markdown]
# ## Load data

# %%
g = GraphLocal('../datasets/sfld_brown_et_al_amidohydrolases_protein_similarities_for_beh.graphml','graphml',' ')
# Out:
# /usr/local/lib/python3.7/site-packages/localgraphclustering/GraphLocal.py:222: UserWarning:
#
# Loading a graphml is not efficient, we suggest using an edgelist format for this API.

# %% [markdown]
# ## TEMP

# %%
G = nx.read_graphml('../datasets/sfld_brown_et_al_amidohydrolases_protein_similarities_for_beh.graphml')

# %%
# groups = np.loadtxt('./datasets/ppi_mips.class', dtype = 'float')
groups = np.loadtxt('../datasets/sfld_brown_et_al_amidohydrolases_protein_similarities_for_beh_ground_truth.csv', dtype = 'str')

groups_by_id = dict()

for node in groups:
    groups_by_id[node[0]] = node[1]

ids_clusters = set()

for node in groups:
    ids_clusters.add(node[1])
    
ids_clusters = list(ids_clusters)

ground_truth_clusters_by_id = dict()

for node in groups:
    ground_truth_clusters_by_id[node[1]] =  []
    
for node in groups:
    ground_truth_clusters_by_id[node[1]].append(node[0])
    
ground_truth_clusters_by_number = dict()

for node in groups:
    ground_truth_clusters_by_number[node[1]] =  []

counter = 0
for node in G.node:
    
    if node == '1.0':
        counter += 1
        continue
    
    what_group = groups_by_id[node]
    ground_truth_clusters_by_number[what_group].append(counter)
    counter += 1
    
all_clusters = []
    
counter = 0
for cluster_id in ground_truth_clusters_by_number:
    
    cluster = ground_truth_clusters_by_number[cluster_id]
    
    if len(cluster) == 1 or len(cluster) == 0:
        counter += 1
        continue

    cond = g.compute_conductance(cluster)
    counter += 1
    
    if cond <= 0.57 and len(cluster) >= 10:
        print("Id: ", cluster_id)
        print("Cluster: ", counter, " conductance: ", cond, "Size: ", len(cluster))
        all_clusters.append(cluster)
# Out:
# Id:  AMP
# Cluster:  6  conductance:  0.5607205113306217 Size:  28
# Id:  urease.0
# Cluster:  29  conductance:  0.42254370102471367 Size:  100

# %% [markdown]
# ## Collect data for ACL (with rounding)

# %%
nodes = {}
external_best_cond_acl = {}
external_best_pre_cond_acl = {}
vol_best_cond_acl = {}
vol_best_pre_acl = {}
size_clust_best_cond_acl = {}
size_clust_best_pre_acl = {}
f1score_best_cond_acl = {}
f1score_best_pre_acl = {}
true_positives_best_cond_acl = {}
true_positives_best_pre_acl = {}
precision_best_cond_acl = {}
precision_best_pre_acl = {}
recall_best_cond_acl = {}
recall_best_pre_acl = {}
cuts_best_cond_acl = {}
cuts_best_pre_acl = {}
cuts_acl_ALL = {}

ct_outer = 0

number_experiments = 0

for rr in all_clusters:
    
    how_many = int(len(rr))
    print(how_many)
    
    random.seed(4)
    
    nodes[ct_outer] = np.random.choice(rr, how_many, replace=False)
    
    eigv, lambda_val = fiedler_local(g, rr)
    lambda_val = np.real(lambda_val)
    
    step = (2*lambda_val - lambda_val/2)/4
    
    a_list = np.arange(lambda_val/2,2*lambda_val,step)
    
    ct = 0
    
    start = time.time()
    
    for node in nodes[ct_outer]:
        ref_node = [node]
        
        max_precision = -1
        min_conduct = 100
        
        ct_inner = 0
        for a in a_list:
            
            if ct_outer <= 1:
                rho = 0.15/np.sum(g.d[rr])
            else:
                rho = 0.2/np.sum(g.d[rr])
            
            output_pr_clustering = approximate_PageRank(g,ref_node,method = "acl", rho=rho, alpha=a, cpp = True, normalize=True,normalized_objective=True)
            number_experiments += 1
            
            output_pr_sc = sweep_cut(g,output_pr_clustering,cpp=True)
            
            S = output_pr_sc[0]
            
            cuts_acl_ALL[ct_outer,node,ct_inner] = S
            
            size_clust_acl_ = len(S)
            
            cond_val_l1pr = g.compute_conductance(S)
            
            vol_ = sum(g.d[S])
            true_positives_acl_ = set(rr).intersection(S)
            if len(true_positives_acl_) == 0:
                true_positives_acl_ = set(ref_node)
                vol_ = g.d[ref_node][0,0]
            precision = sum(g.d[np.array(list(true_positives_acl_))])/vol_
            recall = sum(g.d[np.array(list(true_positives_acl_))])/sum(g.d[rr])
            f1_score_ = 2*(precision*recall)/(precision + recall)
            
            if f1_score_ >= max_precision:
                
                max_precision = f1_score_
                
                external_best_pre_cond_acl[ct_outer,node] = cond_val_l1pr
                vol_best_pre_acl[ct_outer,node] = vol_
                
                size_clust_best_pre_acl[ct_outer,node] = size_clust_acl_
                true_positives_best_pre_acl[ct_outer,node] = true_positives_acl_
                precision_best_pre_acl[ct_outer,node] = precision
                recall_best_pre_acl[ct_outer,node] = recall
                f1score_best_pre_acl[ct_outer,node] = f1_score_
                
                cuts_best_pre_acl[ct_outer,node] = S
        
            if cond_val_l1pr <= min_conduct:
                
                min_conduct = cond_val_l1pr
                
                external_best_cond_acl[ct_outer,node] = cond_val_l1pr
                vol_best_cond_acl[ct_outer,node] = vol_
                
                size_clust_best_cond_acl[ct_outer,node] = size_clust_acl_
                true_positives_best_cond_acl[ct_outer,node] = true_positives_acl_
                precision_best_cond_acl[ct_outer,node] = precision
                recall_best_cond_acl[ct_outer,node] = recall
                f1score_best_cond_acl[ct_outer,node] = f1_score_
                
                cuts_best_cond_acl[ct_outer,node] = S

        print('outer:', ct_outer, 'number of node: ',node, ' completed: ', ct/how_many, ' degree: ', g.d[node])
        print('conductance: ', external_best_cond_acl[ct_outer,node], 'f1score: ', f1score_best_cond_acl[ct_outer,node], 'precision: ', precision_best_cond_acl[ct_outer,node], 'recall: ', recall_best_cond_acl[ct_outer,node])
        ct += 1
    end = time.time()
    print(" ")
    print("Outer: ", ct_outer," Elapsed time ACL with rounding: ", end - start)
    print("Outer: ", ct_outer," Number of experiments: ", number_experiments)
    print(" ")
    ct_outer += 1
# Out:
# 28
# outer: 0 number of node:  215  completed:  0.0  degree:  65.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  195  completed:  0.03571428571428571  degree:  76.0
# conductance:  0.43638525564803804 f1score:  0.8110273327049954 precision:  0.6821244550138724 recall:  1.0
# outer: 0 number of node:  197  completed:  0.07142857142857142  degree:  52.0
# conductance:  0.4329023629068212 f1score:  0.8683148335015136 precision:  0.7672759696834597 recall:  1.0
# outer: 0 number of node:  198  completed:  0.10714285714285714  degree:  52.0
# conductance:  0.4329023629068212 f1score:  0.8683148335015136 precision:  0.7672759696834597 recall:  1.0
# outer: 0 number of node:  216  completed:  0.14285714285714285  degree:  72.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  202  completed:  0.17857142857142858  degree:  54.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  211  completed:  0.21428571428571427  degree:  63.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  212  completed:  0.25  degree:  55.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  203  completed:  0.2857142857142857  degree:  53.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  218  completed:  0.32142857142857145  degree:  52.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  186  completed:  0.35714285714285715  degree:  63.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  185  completed:  0.39285714285714285  degree:  63.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  207  completed:  0.42857142857142855  degree:  63.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  209  completed:  0.4642857142857143  degree:  63.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  205  completed:  0.5  degree:  53.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  213  completed:  0.5357142857142857  degree:  63.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  200  completed:  0.5714285714285714  degree:  45.0
# conductance:  0.4935930292157868 f1score:  0.9373638344226579 precision:  0.8821117375704767 recall:  1.0
# outer: 0 number of node:  206  completed:  0.6071428571428571  degree:  62.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  214  completed:  0.6428571428571429  degree:  67.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  156  completed:  0.6785714285714286  degree:  79.0
# conductance:  0.4397781299524564 f1score:  0.8108362779740872 precision:  0.6818541996830428 recall:  1.0
# outer: 0 number of node:  159  completed:  0.7142857142857143  degree:  65.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  201  completed:  0.75  degree:  63.0
# conductance:  0.4411492122335496 f1score:  0.8873420984789894 precision:  0.7974976830398517 recall:  1.0
# outer: 0 number of node:  210  completed:  0.7857142857142857  degree:  63.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  208  completed:  0.8214285714285714  degree:  63.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  196  completed:  0.8571428571428571  degree:  67.0
# conductance:  0.4319714399047997 f1score:  0.8114097123998114 precision:  0.682665608885363 recall:  1.0
# outer: 0 number of node:  217  completed:  0.8928571428571429  degree:  67.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  160  completed:  0.9285714285714286  degree:  66.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  204  completed:  0.9642857142857143  degree:  52.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
#
# Outer:  0  Elapsed time ACL with rounding:  2.6006581783294678
# Outer:  0  Number of experiments:  112
#
# 100
# outer: 1 number of node:  28  completed:  0.0  degree:  166.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  20  completed:  0.01  degree:  181.0
# conductance:  0.490449148167269 f1score:  0.5769436997319034 precision:  0.590216830149716 recall:  0.5642544265531495
# outer: 1 number of node:  130  completed:  0.02  degree:  170.0
# conductance:  0.4628615602654126 f1score:  0.6337585621818639 precision:  0.6457706345648973 recall:  0.622185205749892
# outer: 1 number of node:  63  completed:  0.03  degree:  165.0
# conductance:  0.4591843309065138 f1score:  0.6701017971597335 precision:  0.6827581791407901 recall:  0.6579061015485225
# outer: 1 number of node:  76  completed:  0.04  degree:  155.0
# conductance:  0.4220264317180617 f1score:  0.7191375141418398 precision:  0.5614478697609976 recall:  1.0
# outer: 1 number of node:  93  completed:  0.05  degree:  161.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  79  completed:  0.06  degree:  155.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  15  completed:  0.07  degree:  166.0
# conductance:  0.4544609665427509 f1score:  0.7172599951324203 precision:  0.5591624120325652 recall:  1.0
# outer: 1 number of node:  66  completed:  0.08  degree:  155.0
# conductance:  0.4220264317180617 f1score:  0.7191375141418398 precision:  0.5614478697609976 recall:  1.0
# outer: 1 number of node:  69  completed:  0.09  degree:  152.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  58  completed:  0.1  degree:  162.0
# conductance:  0.45659890287189414 f1score:  0.6909022414767375 precision:  0.7033557046979866 recall:  0.6788821025356283
# outer: 1 number of node:  102  completed:  0.11  degree:  150.0
# conductance:  0.43029680071951687 f1score:  0.7850737815813484 precision:  0.801078720945165 recall:  0.7696958479856869
# outer: 1 number of node:  107  completed:  0.12  degree:  161.0
# conductance:  0.44196543719370646 f1score:  0.7220878741245564 precision:  0.7354145342886387 recall:  0.7092356098463817
# outer: 1 number of node:  65  completed:  0.13  degree:  165.0
# conductance:  0.4591843309065138 f1score:  0.6701017971597335 precision:  0.6827581791407901 recall:  0.6579061015485225
# outer: 1 number of node:  42  completed:  0.14  degree:  155.0
# conductance:  0.44640329429931797 f1score:  0.82742792467067 precision:  0.8436337992050262 recall:  0.8118329323215497
# outer: 1 number of node:  31  completed:  0.15  degree:  166.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  50  completed:  0.16  degree:  171.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  47  completed:  0.17  degree:  159.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  112  completed:  0.18  degree:  164.0
# conductance:  0.4508435136707388 f1score:  0.6907585168454733 precision:  0.7026613057629715 recall:  0.6792522672589302
# outer: 1 number of node:  91  completed:  0.19  degree:  155.0
# conductance:  0.4413695456300682 f1score:  0.8588224199176385 precision:  0.8755287783617485 recall:  0.8427416867172558
# outer: 1 number of node:  62  completed:  0.2  degree:  160.0
# conductance:  0.44914816726897266 f1score:  0.7207484381376951 precision:  0.7337637432881616 recall:  0.7081868097970263
# outer: 1 number of node:  97  completed:  0.21  degree:  163.0
# conductance:  0.42488888888888887 f1score:  0.7188185990820195 precision:  0.5610591900311527 recall:  1.0
# outer: 1 number of node:  72  completed:  0.22  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  116  completed:  0.23  degree:  156.0
# conductance:  0.4406714009038089 f1score:  0.7417056404783577 precision:  0.7549520766773163 recall:  0.728916034301931
# outer: 1 number of node:  67  completed:  0.24  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  101  completed:  0.25  degree:  150.0
# conductance:  0.43092247726288435 f1score:  0.7197602131438721 precision:  0.5622073462592349 recall:  1.0
# outer: 1 number of node:  71  completed:  0.26  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  96  completed:  0.27  degree:  168.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  120  completed:  0.28  degree:  167.0
# conductance:  0.4677027683341428 f1score:  0.7157871494811217 precision:  0.5573742305972972 recall:  1.0
# outer: 1 number of node:  94  completed:  0.29  degree:  167.0
# conductance:  0.46063220240777697 f1score:  0.6440784510937893 precision:  0.6565002883321587 recall:  0.6321179591584922
# outer: 1 number of node:  70  completed:  0.3  degree:  169.0
# conductance:  0.46107861412868806 f1score:  0.6438330290247435 precision:  0.6573246769942791 recall:  0.6308840767474859
# outer: 1 number of node:  100  completed:  0.31  degree:  163.0
# conductance:  0.44999354755452314 f1score:  0.7030234529528115 precision:  0.715765247410817 recall:  0.6907273736812882
# outer: 1 number of node:  53  completed:  0.32  degree:  179.0
# conductance:  0.4877450980392157 f1score:  0.5941906107709216 precision:  0.6050780250703505 recall:  0.5836880745264976
# outer: 1 number of node:  105  completed:  0.33  degree:  148.0
# conductance:  0.4220264317180617 f1score:  0.7191375141418398 precision:  0.5614478697609976 recall:  1.0
# outer: 1 number of node:  57  completed:  0.34  degree:  162.0
# conductance:  0.4472497745716862 f1score:  0.7183089229132968 precision:  0.5604384205794897 recall:  1.0
# outer: 1 number of node:  43  completed:  0.35  degree:  151.0
# conductance:  0.44023173479240424 f1score:  0.7631860187338906 precision:  0.7779557834027555 recall:  0.7489666234807822
# outer: 1 number of node:  106  completed:  0.36  degree:  160.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  124  completed:  0.37  degree:  172.0
# conductance:  0.4718709677419355 f1score:  0.6138340293258815 precision:  0.625 recall:  0.6030600283792954
# outer: 1 number of node:  123  completed:  0.38  degree:  172.0
# conductance:  0.4799845041322314 f1score:  0.6168407104773322 precision:  0.631198347107438 recall:  0.6031217224998457
# outer: 1 number of node:  80  completed:  0.39  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  133  completed:  0.4  degree:  170.0
# conductance:  0.46358084217293477 f1score:  0.6251101876337993 precision:  0.6382513661202186 recall:  0.6124992288234932
# outer: 1 number of node:  118  completed:  0.41  degree:  175.0
# conductance:  0.4791948035243424 f1score:  0.6154088050314467 precision:  0.6276056699377847 recall:  0.6036769695847986
# outer: 1 number of node:  108  completed:  0.42  degree:  174.0
# conductance:  0.4398547435315479 f1score:  0.718070260931201 precision:  0.5601479075232402 recall:  1.0
# outer: 1 number of node:  73  completed:  0.43  degree:  161.0
# conductance:  0.4383249886208466 f1score:  0.7179748405386251 precision:  0.560031786615071 recall:  1.0
# outer: 1 number of node:  99  completed:  0.44  degree:  157.0
# conductance:  0.43430703899112083 f1score:  0.7649522849674026 precision:  0.781366619482692 recall:  0.7492133999629835
# outer: 1 number of node:  55  completed:  0.45  degree:  159.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  45  completed:  0.46  degree:  159.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  127  completed:  0.47  degree:  157.0
# conductance:  0.45248373171831713 f1score:  0.8081563403292698 precision:  0.823420193354248 recall:  0.7934480843975569
# outer: 1 number of node:  122  completed:  0.48  degree:  166.0
# conductance:  0.4677027683341428 f1score:  0.7157871494811217 precision:  0.5573742305972972 recall:  1.0
# outer: 1 number of node:  115  completed:  0.49  degree:  171.0
# conductance:  0.4881198347107438 f1score:  0.6769725841562293 precision:  0.6927298553719008 recall:  0.6619162193842927
# outer: 1 number of node:  132  completed:  0.5  degree:  162.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  114  completed:  0.51  degree:  163.0
# conductance:  0.46531586758727495 f1score:  0.6766542610231502 precision:  0.6921984900303284 recall:  0.6617928311431921
# outer: 1 number of node:  131  completed:  0.52  degree:  168.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  75  completed:  0.53  degree:  167.0
# conductance:  0.44236902050113897 f1score:  0.7179430393763565 precision:  0.5599930903437554 recall:  1.0
# outer: 1 number of node:  87  completed:  0.54  degree:  157.0
# conductance:  0.42488888888888887 f1score:  0.7188185990820195 precision:  0.5610591900311527 recall:  1.0
# outer: 1 number of node:  78  completed:  0.55  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  85  completed:  0.56  degree:  144.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  121  completed:  0.57  degree:  167.0
# conductance:  0.4677027683341428 f1score:  0.7157871494811217 precision:  0.5573742305972972 recall:  1.0
# outer: 1 number of node:  51  completed:  0.58  degree:  157.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  113  completed:  0.59  degree:  163.0
# conductance:  0.46531586758727495 f1score:  0.6766542610231502 precision:  0.6921984900303284 recall:  0.6617928311431921
# outer: 1 number of node:  46  completed:  0.6  degree:  161.0
# conductance:  0.4398547435315479 f1score:  0.718070260931201 precision:  0.5601479075232402 recall:  1.0
# outer: 1 number of node:  83  completed:  0.61  degree:  148.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  90  completed:  0.62  degree:  161.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  54  completed:  0.63  degree:  154.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  84  completed:  0.64  degree:  157.0
# conductance:  0.42488888888888887 f1score:  0.7188185990820195 precision:  0.5610591900311527 recall:  1.0
# outer: 1 number of node:  59  completed:  0.65  degree:  169.0
# conductance:  0.47651960467670046 f1score:  0.6349943517007656 precision:  0.6461459863337378 recall:  0.6242211117280523
# outer: 1 number of node:  89  completed:  0.66  degree:  149.0
# conductance:  0.4370341814443588 f1score:  0.76488909863143 precision:  0.7804314329738059 recall:  0.7499537294095873
# outer: 1 number of node:  117  completed:  0.67  degree:  163.0
# conductance:  0.46531586758727495 f1score:  0.6766542610231502 precision:  0.6921984900303284 recall:  0.6617928311431921
# outer: 1 number of node:  77  completed:  0.68  degree:  167.0
# conductance:  0.44236902050113897 f1score:  0.7179430393763565 precision:  0.5599930903437554 recall:  1.0
# outer: 1 number of node:  17  completed:  0.69  degree:  164.0
# conductance:  0.46182519280205653 f1score:  0.6843148981711733 precision:  0.6985861182519281 recall:  0.6706150903818866
# outer: 1 number of node:  88  completed:  0.7  degree:  161.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  48  completed:  0.71  degree:  159.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  40  completed:  0.72  degree:  153.0
# conductance:  0.4428947875827495 f1score:  0.7328090594526581 precision:  0.7475771773313651 recall:  0.718613116170029
# outer: 1 number of node:  60  completed:  0.73  degree:  147.0
# conductance:  0.4406757802424555 f1score:  0.8066329575076159 precision:  0.8215199590583419 recall:  0.792275896107101
# outer: 1 number of node:  104  completed:  0.74  degree:  154.0
# conductance:  0.4256546826453617 f1score:  0.7188664183076104 precision:  0.5611174576799253 recall:  1.0
# outer: 1 number of node:  128  completed:  0.75  degree:  170.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  64  completed:  0.76  degree:  167.0
# conductance:  0.44236902050113897 f1score:  0.7179430393763565 precision:  0.5599930903437554 recall:  1.0
# outer: 1 number of node:  129  completed:  0.77  degree:  169.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  49  completed:  0.78  degree:  160.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  52  completed:  0.79  degree:  159.0
# conductance:  0.4385805277525023 f1score:  0.7179907421762529 precision:  0.5600511367562712 recall:  1.0
# outer: 1 number of node:  111  completed:  0.8  degree:  158.0
# conductance:  0.4549897119341564 f1score:  0.6928955561845457 precision:  0.7066974595842956 recall:  0.679622431982232
# outer: 1 number of node:  56  completed:  0.81  degree:  159.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  44  completed:  0.82  degree:  153.0
# conductance:  0.44359932963774656 f1score:  0.7522538087011151 precision:  0.7662869576347113 recall:  0.7387253994694306
# outer: 1 number of node:  92  completed:  0.83  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  125  completed:  0.84  degree:  168.0
# conductance:  0.47747980613893376 f1score:  0.6104034636380749 precision:  0.6210022342802426 recall:  0.6001604047134308
# outer: 1 number of node:  109  completed:  0.85  degree:  174.0
# conductance:  0.4398547435315479 f1score:  0.718070260931201 precision:  0.5601479075232402 recall:  1.0
# outer: 1 number of node:  98  completed:  0.86  degree:  159.0
# conductance:  0.43804312841969745 f1score:  0.7549143145161291 precision:  0.7712906340521404 recall:  0.7392189524338331
# outer: 1 number of node:  103  completed:  0.87  degree:  150.0
# conductance:  0.4158541754980924 f1score:  0.7205601244721048 precision:  0.5631840450297071 recall:  1.0
# outer: 1 number of node:  21  completed:  0.88  degree:  181.0
# conductance:  0.492986878676233 f1score:  0.5864859777903255 precision:  0.5965919969366265 recall:  0.5767166389043125
# outer: 1 number of node:  74  completed:  0.89  degree:  163.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  110  completed:  0.9  degree:  167.0
# conductance:  0.4425144747725393 f1score:  0.7215063096748346 precision:  0.5643409233340296 recall:  1.0
# outer: 1 number of node:  68  completed:  0.91  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  61  completed:  0.92  degree:  155.0
# conductance:  0.4220264317180617 f1score:  0.7191375141418398 precision:  0.5614478697609976 recall:  1.0
# outer: 1 number of node:  119  completed:  0.93  degree:  178.0
# conductance:  0.4796569733703011 f1score:  0.587615864808626 precision:  0.6008769101811852 recall:  0.5749275094083534
# outer: 1 number of node:  86  completed:  0.94  degree:  162.0
# conductance:  0.42718446601941745 f1score:  0.7190737084932235 precision:  0.5613700907390732 recall:  1.0
# outer: 1 number of node:  126  completed:  0.95  degree:  167.0
# conductance:  0.4677027683341428 f1score:  0.7157871494811217 precision:  0.5573742305972972 recall:  1.0
# outer: 1 number of node:  41  completed:  0.96  degree:  153.0
# conductance:  0.4428947875827495 f1score:  0.7328090594526581 precision:  0.7475771773313651 recall:  0.718613116170029
# outer: 1 number of node:  82  completed:  0.97  degree:  162.0
# conductance:  0.45195591931430046 f1score:  0.6941309966588918 precision:  0.7096088161371399 recall:  0.6793139613794805
# outer: 1 number of node:  95  completed:  0.98  degree:  148.0
# conductance:  0.4337148000514337 f1score:  0.7536441771872933 precision:  0.7695126655522695 recall:  0.738416928866679
# outer: 1 number of node:  81  completed:  0.99  degree:  160.0
# conductance:  0.44459770114942526 f1score:  0.7176251826271749 precision:  0.5596064215432418 recall:  1.0
#
# Outer:  1  Elapsed time ACL with rounding:  17.6720449924469
# Outer:  1  Number of experiments:  512

# %% [markdown]
# ## Performance of ACL (with rounding).

# %%
all_data = []
xlabels_ = []

print('Results for ACL with rounding')
sum_precision = 0
sum_recall = 0
sum_f1 = 0
sum_conductance = 0

info_ref_nodes = all_clusters
l_info_ref_nodes = len(info_ref_nodes)

for i in range(l_info_ref_nodes):
    temp_pre = []
    temp_rec = []
    temp_f1 = []
    temp_conductance = []
    
    for j in all_clusters[i]:
        temp_pre.append(precision_best_cond_acl[i,j])
        temp_rec.append(recall_best_cond_acl[i,j])
        temp_f1.append(f1score_best_cond_acl[i,j])
        temp_conductance.append(external_best_cond_acl[i,j])
    
    print('Feature:', i,'Precision', stat_.mean(temp_pre), 'Recall', stat_.mean(temp_rec), 'F1', stat_.mean(temp_f1), 'Cond.', stat_.mean(temp_conductance))

np.save('results/f1score_best_pre_acl_ORKUT', f1score_best_pre_acl) 
np.save('results/precision_best_pre_acl_ORKUT', precision_best_pre_acl) 
np.save('results/recall_best_pre_acl_ORKUT', recall_best_pre_acl)
# Out:
# Results for ACL with rounding
# Feature: 0 Precision 0.7616010784971015 Recall 1.0 F1 0.8639590510056822 Cond. 0.4298763868141641
# Feature: 1 Precision 0.6213475956513441 Recall 0.869310876673453 F1 0.7087703363309276 Cond. 0.4418880201742084

# %% [markdown]
# ## Collect data for l1-reg. PR (with rounding)

# %%
nodes = {}
external_best_cond_acl = {}
external_best_pre_cond_acl = {}
vol_best_cond_acl = {}
vol_best_pre_acl = {}
size_clust_best_cond_acl = {}
size_clust_best_pre_acl = {}
f1score_best_cond_acl = {}
f1score_best_pre_acl = {}
true_positives_best_cond_acl = {}
true_positives_best_pre_acl = {}
precision_best_cond_acl = {}
precision_best_pre_acl = {}
recall_best_cond_acl = {}
recall_best_pre_acl = {}
cuts_best_cond_acl = {}
cuts_best_pre_acl = {}
cuts_acl_ALL = {}

ct_outer = 0

number_experiments = 0

for rr in all_clusters:
    
    how_many = int(len(rr))
    print(how_many)
    
    random.seed(4)
    
    nodes[ct_outer] = np.random.choice(rr, how_many, replace=False)
    
    eigv, lambda_val = fiedler_local(g, rr)
    lambda_val = np.real(lambda_val)
    
    step = (2*lambda_val - lambda_val/2)/4
    
    a_list = np.arange(lambda_val/2,2*lambda_val,step)
    
    ct = 0
    
    start = time.time()
    
    for node in nodes[ct_outer]:
        ref_node = [node]
        
        max_precision = -1
        min_conduct = 100
        
        ct_inner = 0
        for a in a_list:
            
            if ct_outer <= 1:
                rho = 0.15/np.sum(g.d[rr])
            else:
                rho = 0.2/np.sum(g.d[rr])
            
            output_pr_clustering = approximate_PageRank(g,ref_node,method = "l1reg-rand", epsilon=1.0e-2, rho=rho, alpha=a, cpp = True, normalize=True,normalized_objective=True)
            number_experiments += 1
            
            output_pr_sc = sweep_cut(g,output_pr_clustering,cpp=True)
            
            S = output_pr_sc[0]
            
            cuts_acl_ALL[ct_outer,node,ct_inner] = S
            
            size_clust_acl_ = len(S)
            
            cond_val_l1pr = g.compute_conductance(S)
            
            vol_ = sum(g.d[S])
            true_positives_acl_ = set(rr).intersection(S)
            if len(true_positives_acl_) == 0:
                true_positives_acl_ = set(ref_node)
                vol_ = g.d[ref_node][0,0]
            precision = sum(g.d[np.array(list(true_positives_acl_))])/vol_
            recall = sum(g.d[np.array(list(true_positives_acl_))])/sum(g.d[rr])
            f1_score_ = 2*(precision*recall)/(precision + recall)
            
            if f1_score_ >= max_precision:
                
                max_precision = f1_score_
                
                external_best_pre_cond_acl[ct_outer,node] = cond_val_l1pr
                vol_best_pre_acl[ct_outer,node] = vol_
                
                size_clust_best_pre_acl[ct_outer,node] = size_clust_acl_
                true_positives_best_pre_acl[ct_outer,node] = true_positives_acl_
                precision_best_pre_acl[ct_outer,node] = precision
                recall_best_pre_acl[ct_outer,node] = recall
                f1score_best_pre_acl[ct_outer,node] = f1_score_
                
                cuts_best_pre_acl[ct_outer,node] = S
        
            if cond_val_l1pr <= min_conduct:
                
                min_conduct = cond_val_l1pr
                
                external_best_cond_acl[ct_outer,node] = cond_val_l1pr
                vol_best_cond_acl[ct_outer,node] = vol_
                
                size_clust_best_cond_acl[ct_outer,node] = size_clust_acl_
                true_positives_best_cond_acl[ct_outer,node] = true_positives_acl_
                precision_best_cond_acl[ct_outer,node] = precision
                recall_best_cond_acl[ct_outer,node] = recall
                f1score_best_cond_acl[ct_outer,node] = f1_score_
                
                cuts_best_cond_acl[ct_outer,node] = S

        print('outer:', ct_outer, 'number of node: ',node, ' completed: ', ct/how_many, ' degree: ', g.d[node])
        print('conductance: ', external_best_cond_acl[ct_outer,node], 'f1score: ', f1score_best_cond_acl[ct_outer,node], 'precision: ', precision_best_cond_acl[ct_outer,node], 'recall: ', recall_best_cond_acl[ct_outer,node])
        ct += 1

    end = time.time()
    print(" ")
    print("Outer: ", ct_outer," Elapsed time l1-reg. with rounding: ", end - start)
    print("Outer: ", ct_outer," Number of experiments: ", number_experiments)
    print(" ")
    ct_outer += 1
# Out:
# 28
# outer: 0 number of node:  208  completed:  0.0  degree:  63.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  202  completed:  0.03571428571428571  degree:  54.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  213  completed:  0.07142857142857142  degree:  63.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  216  completed:  0.10714285714285714  degree:  72.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  195  completed:  0.14285714285714285  degree:  76.0
# conductance:  0.43638525564803804 f1score:  0.8110273327049954 precision:  0.6821244550138724 recall:  1.0
# outer: 0 number of node:  160  completed:  0.17857142857142858  degree:  66.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  205  completed:  0.21428571428571427  degree:  53.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  200  completed:  0.25  degree:  45.0
# conductance:  0.4935930292157868 f1score:  0.9373638344226579 precision:  0.8821117375704767 recall:  1.0
# outer: 0 number of node:  198  completed:  0.2857142857142857  degree:  52.0
# conductance:  0.4329023629068212 f1score:  0.8683148335015136 precision:  0.7672759696834597 recall:  1.0
# outer: 0 number of node:  201  completed:  0.32142857142857145  degree:  63.0
# conductance:  0.4411492122335496 f1score:  0.8873420984789894 precision:  0.7974976830398517 recall:  1.0
# outer: 0 number of node:  156  completed:  0.35714285714285715  degree:  79.0
# conductance:  0.4397781299524564 f1score:  0.8108362779740872 precision:  0.6818541996830428 recall:  1.0
# outer: 0 number of node:  215  completed:  0.39285714285714285  degree:  65.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  207  completed:  0.42857142857142855  degree:  63.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  186  completed:  0.4642857142857143  degree:  63.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  206  completed:  0.5  degree:  62.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  212  completed:  0.5357142857142857  degree:  55.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  204  completed:  0.5714285714285714  degree:  52.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  209  completed:  0.6071428571428571  degree:  63.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  217  completed:  0.6428571428571429  degree:  67.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  218  completed:  0.6785714285714286  degree:  52.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  210  completed:  0.7142857142857143  degree:  63.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  214  completed:  0.75  degree:  67.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  185  completed:  0.7857142857142857  degree:  63.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  203  completed:  0.8214285714285714  degree:  53.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  211  completed:  0.8571428571428571  degree:  63.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  159  completed:  0.8928571428571429  degree:  65.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  196  completed:  0.9285714285714286  degree:  67.0
# conductance:  0.4319714399047997 f1score:  0.8114097123998114 precision:  0.682665608885363 recall:  1.0
# outer: 0 number of node:  197  completed:  0.9642857142857143  degree:  52.0
# conductance:  0.4329023629068212 f1score:  0.8683148335015136 precision:  0.7672759696834597 recall:  1.0
#
# Outer:  0  Elapsed time l1-reg. with rounding:  0.1297757625579834
# Outer:  0  Number of experiments:  112
#
# 100
# outer: 1 number of node:  56  completed:  0.0  degree:  159.0
# conductance:  0.4305582383619857 f1score:  0.8584120982986768 precision:  0.8771489279505505 recall:  0.8404590042568943
# outer: 1 number of node:  54  completed:  0.01  degree:  154.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  73  completed:  0.02  degree:  161.0
# conductance:  0.4383249886208466 f1score:  0.7179748405386251 precision:  0.560031786615071 recall:  1.0
# outer: 1 number of node:  107  completed:  0.03  degree:  161.0
# conductance:  0.4397112843977573 f1score:  0.8548630309122895 precision:  0.8708954746207515 recall:  0.839410204207539
# outer: 1 number of node:  89  completed:  0.04  degree:  149.0
# conductance:  0.4310378148553759 f1score:  0.8761390058442783 precision:  0.8927450854837677 recall:  0.8601394287124438
# outer: 1 number of node:  100  completed:  0.05  degree:  163.0
# conductance:  0.44243049732309875 f1score:  0.8440620486089305 precision:  0.8594999040736714 recall:  0.8291689801961873
# outer: 1 number of node:  53  completed:  0.06  degree:  179.0
# conductance:  0.4856223866194918 f1score:  0.7211689865843673 precision:  0.736571244773239 recall:  0.7063976803010673
# outer: 1 number of node:  46  completed:  0.07  degree:  161.0
# conductance:  0.4398547435315479 f1score:  0.718070260931201 precision:  0.5601479075232402 recall:  1.0
# outer: 1 number of node:  76  completed:  0.08  degree:  155.0
# conductance:  0.4220264317180617 f1score:  0.7191375141418398 precision:  0.5614478697609976 recall:  1.0
# outer: 1 number of node:  86  completed:  0.09  degree:  162.0
# conductance:  0.42718446601941745 f1score:  0.7190737084932235 precision:  0.5613700907390732 recall:  1.0
# outer: 1 number of node:  131  completed:  0.1  degree:  168.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  72  completed:  0.11  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  50  completed:  0.12  degree:  171.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  58  completed:  0.13  degree:  162.0
# conductance:  0.4520724553600206 f1score:  0.8125392637265988 precision:  0.8276700582325462 recall:  0.7979517551977297
# outer: 1 number of node:  132  completed:  0.14  degree:  162.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  123  completed:  0.15  degree:  172.0
# conductance:  0.47702407002188185 f1score:  0.7410644116814938 precision:  0.7554800666581207 recall:  0.7271885989265223
# outer: 1 number of node:  120  completed:  0.16  degree:  167.0
# conductance:  0.4688465499485067 f1score:  0.7407034859962908 precision:  0.7550628044091259 recall:  0.7268801283237707
# outer: 1 number of node:  105  completed:  0.17  degree:  148.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  119  completed:  0.18  degree:  178.0
# conductance:  0.4819532908704883 f1score:  0.7418726026535875 precision:  0.7564275181124576 recall:  0.7278672342525757
# outer: 1 number of node:  15  completed:  0.19  degree:  166.0
# conductance:  0.44902023771281724 f1score:  0.8138729779064643 precision:  0.8307099261162866 recall:  0.7977049787155284
# outer: 1 number of node:  42  completed:  0.2  degree:  155.0
# conductance:  0.435801914059991 f1score:  0.8456261799874135 precision:  0.8629503564318284 recall:  0.8289838978345364
# outer: 1 number of node:  87  completed:  0.21  degree:  157.0
# conductance:  0.42488888888888887 f1score:  0.7188185990820195 precision:  0.5610591900311527 recall:  1.0
# outer: 1 number of node:  122  completed:  0.22  degree:  166.0
# conductance:  0.4688465499485067 f1score:  0.7407034859962908 precision:  0.7550628044091259 recall:  0.7268801283237707
# outer: 1 number of node:  63  completed:  0.23  degree:  165.0
# conductance:  0.45503701319600903 f1score:  0.7919783743006223 precision:  0.8073053508490868 recall:  0.777222530692825
# outer: 1 number of node:  65  completed:  0.24  degree:  165.0
# conductance:  0.45503701319600903 f1score:  0.7919783743006223 precision:  0.8073053508490868 recall:  0.777222530692825
# outer: 1 number of node:  85  completed:  0.25  degree:  144.0
# conductance:  0.412263787119167 f1score:  0.9098750275443069 precision:  0.928911171101684 recall:  0.8916034301931026
# outer: 1 number of node:  64  completed:  0.26  degree:  167.0
# conductance:  0.44236902050113897 f1score:  0.7179430393763565 precision:  0.5599930903437554 recall:  1.0
# outer: 1 number of node:  114  completed:  0.27  degree:  163.0
# conductance:  0.45672952725393956 f1score:  0.7814216224697944 precision:  0.7952222789984671 recall:  0.7680918008513788
# outer: 1 number of node:  130  completed:  0.28  degree:  170.0
# conductance:  0.4683935820606998 f1score:  0.7535300050428644 precision:  0.770281590308654 recall:  0.7374915170584243
# outer: 1 number of node:  81  completed:  0.29  degree:  160.0
# conductance:  0.44370007729966504 f1score:  0.8360381936785051 precision:  0.8544833805720176 recall:  0.8183725090998828
# outer: 1 number of node:  66  completed:  0.3  degree:  155.0
# conductance:  0.4220264317180617 f1score:  0.7191375141418398 precision:  0.5614478697609976 recall:  1.0
# outer: 1 number of node:  117  completed:  0.31  degree:  163.0
# conductance:  0.45672952725393956 f1score:  0.7814216224697944 precision:  0.7952222789984671 recall:  0.7680918008513788
# outer: 1 number of node:  118  completed:  0.32  degree:  175.0
# conductance:  0.4774380431284197 f1score:  0.7215851814516128 precision:  0.7372384937238494 recall:  0.7065827626627182
# outer: 1 number of node:  68  completed:  0.33  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  113  completed:  0.34  degree:  163.0
# conductance:  0.45672952725393956 f1score:  0.7814216224697944 precision:  0.7952222789984671 recall:  0.7680918008513788
# outer: 1 number of node:  98  completed:  0.35  degree:  159.0
# conductance:  0.43260953359886933 f1score:  0.8454834345404776 precision:  0.8627199178117375 recall:  0.8289222037139861
# outer: 1 number of node:  77  completed:  0.36  degree:  167.0
# conductance:  0.44236902050113897 f1score:  0.7179430393763565 precision:  0.5599930903437554 recall:  1.0
# outer: 1 number of node:  62  completed:  0.37  degree:  160.0
# conductance:  0.45236405856930917 f1score:  0.8014193305281668 precision:  0.8160772526699495 recall:  0.7872786723425258
# outer: 1 number of node:  49  completed:  0.38  degree:  160.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  121  completed:  0.39  degree:  167.0
# conductance:  0.4688465499485067 f1score:  0.7407034859962908 precision:  0.7550628044091259 recall:  0.7268801283237707
# outer: 1 number of node:  102  completed:  0.4  degree:  150.0
# conductance:  0.4220264317180617 f1score:  0.7191375141418398 precision:  0.5614478697609976 recall:  1.0
# outer: 1 number of node:  67  completed:  0.41  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  71  completed:  0.42  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  111  completed:  0.43  degree:  158.0
# conductance:  0.4488168724279835 f1score:  0.8026543384596032 precision:  0.8186425455478573 recall:  0.7872786723425258
# outer: 1 number of node:  43  completed:  0.44  degree:  151.0
# conductance:  0.4288659793814433 f1score:  0.8897223360332819 precision:  0.9094716494845361 recall:  0.8708125115676476
# outer: 1 number of node:  31  completed:  0.45  degree:  166.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  28  completed:  0.46  degree:  166.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  70  completed:  0.47  degree:  169.0
# conductance:  0.4585720723620679 f1score:  0.7635939764350073 precision:  0.7802098757484066 recall:  0.7476710469492257
# outer: 1 number of node:  83  completed:  0.48  degree:  148.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  94  completed:  0.49  degree:  167.0
# conductance:  0.4624236579877853 f1score:  0.7735171892708728 precision:  0.789778206364513 recall:  0.7579122709605774
# outer: 1 number of node:  82  completed:  0.5  degree:  162.0
# conductance:  0.44350628424105704 f1score:  0.8362753751103266 precision:  0.8549790525298099 recall:  0.8183725090998828
# outer: 1 number of node:  55  completed:  0.51  degree:  159.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  48  completed:  0.52  degree:  159.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  106  completed:  0.53  degree:  160.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  116  completed:  0.54  degree:  156.0
# conductance:  0.4327108821635544 f1score:  0.857619962821765 precision:  0.8763683193818416 recall:  0.8396569806897403
# outer: 1 number of node:  129  completed:  0.55  degree:  169.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  61  completed:  0.56  degree:  155.0
# conductance:  0.4220264317180617 f1score:  0.7191375141418398 precision:  0.5614478697609976 recall:  1.0
# outer: 1 number of node:  124  completed:  0.57  degree:  172.0
# conductance:  0.4639308297844883 f1score:  0.7408872562870867 precision:  0.7543153049482163 recall:  0.7279289283731261
# outer: 1 number of node:  57  completed:  0.58  degree:  162.0
# conductance:  0.4472497745716862 f1score:  0.7183089229132968 precision:  0.5604384205794897 recall:  1.0
# outer: 1 number of node:  93  completed:  0.59  degree:  161.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  95  completed:  0.6  degree:  148.0
# conductance:  0.4220264317180617 f1score:  0.7191375141418398 precision:  0.5614478697609976 recall:  1.0
# outer: 1 number of node:  92  completed:  0.61  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  127  completed:  0.62  degree:  157.0
# conductance:  0.4473563218390805 f1score:  0.7176251826271749 precision:  0.5596064215432418 recall:  1.0
# outer: 1 number of node:  115  completed:  0.63  degree:  171.0
# conductance:  0.4806201550387597 f1score:  0.7498823307916784 precision:  0.7630268199233716 recall:  0.7371830464556728
# outer: 1 number of node:  44  completed:  0.64  degree:  153.0
# conductance:  0.4359205776173285 f1score:  0.8792282714920716 precision:  0.8989814337287262 recall:  0.8603245110740947
# outer: 1 number of node:  60  completed:  0.65  degree:  147.0
# conductance:  0.43228797733273233 f1score:  0.8786312937173104 precision:  0.8978685040891236 recall:  0.860201122832994
# outer: 1 number of node:  45  completed:  0.66  degree:  159.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  101  completed:  0.67  degree:  150.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  96  completed:  0.68  degree:  168.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  88  completed:  0.69  degree:  161.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  109  completed:  0.7  degree:  174.0
# conductance:  0.4398547435315479 f1score:  0.718070260931201 precision:  0.5601479075232402 recall:  1.0
# outer: 1 number of node:  125  completed:  0.71  degree:  168.0
# conductance:  0.473799548823719 f1score:  0.7402148646101653 precision:  0.754048 recall:  0.7268801283237707
# outer: 1 number of node:  69  completed:  0.72  degree:  152.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  91  completed:  0.73  degree:  155.0
# conductance:  0.430298353909465 f1score:  0.8882598987325848 precision:  0.9059532974082628 recall:  0.8712443704114998
# outer: 1 number of node:  79  completed:  0.74  degree:  155.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  80  completed:  0.75  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  52  completed:  0.76  degree:  159.0
# conductance:  0.4385805277525023 f1score:  0.7179907421762529 precision:  0.5600511367562712 recall:  1.0
# outer: 1 number of node:  20  completed:  0.77  degree:  181.0
# conductance:  0.49607515120319134 f1score:  0.6596957576139334 precision:  0.6738514991635568 recall:  0.6461225245234129
# outer: 1 number of node:  84  completed:  0.78  degree:  157.0
# conductance:  0.42488888888888887 f1score:  0.7188185990820195 precision:  0.5610591900311527 recall:  1.0
# outer: 1 number of node:  103  completed:  0.79  degree:  150.0
# conductance:  0.4158541754980924 f1score:  0.7205601244721048 precision:  0.5631840450297071 recall:  1.0
# outer: 1 number of node:  51  completed:  0.8  degree:  157.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  21  completed:  0.81  degree:  181.0
# conductance:  0.4950832315701523 f1score:  0.6804331402669352 precision:  0.6946461854874992 recall:  0.6667900549077673
# outer: 1 number of node:  97  completed:  0.82  degree:  163.0
# conductance:  0.42488888888888887 f1score:  0.7188185990820195 precision:  0.5610591900311527 recall:  1.0
# outer: 1 number of node:  90  completed:  0.83  degree:  161.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  133  completed:  0.84  degree:  170.0
# conductance:  0.47087857847976305 f1score:  0.7152659797453831 precision:  0.5567424606718417 recall:  1.0
# outer: 1 number of node:  75  completed:  0.85  degree:  167.0
# conductance:  0.44236902050113897 f1score:  0.7179430393763565 precision:  0.5599930903437554 recall:  1.0
# outer: 1 number of node:  17  completed:  0.86  degree:  164.0
# conductance:  0.4524851918619624 f1score:  0.8031555457774144 precision:  0.8186186570989237 recall:  0.7882657782713307
# outer: 1 number of node:  78  completed:  0.87  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  47  completed:  0.88  degree:  159.0
# conductance:  0.4126234435379991 f1score:  0.7200799644602399 precision:  0.5625976189649786 recall:  1.0
# outer: 1 number of node:  41  completed:  0.89  degree:  153.0
# conductance:  0.4339890357949049 f1score:  0.8652179374450445 precision:  0.8811000959385993 recall:  0.849898204701092
# outer: 1 number of node:  59  completed:  0.9  degree:  169.0
# conductance:  0.47647814910025704 f1score:  0.7722797193997923 precision:  0.7878690629011553 recall:  0.7572953297550743
# outer: 1 number of node:  126  completed:  0.91  degree:  167.0
# conductance:  0.4688465499485067 f1score:  0.7407034859962908 precision:  0.7550628044091259 recall:  0.7268801283237707
# outer: 1 number of node:  110  completed:  0.92  degree:  167.0
# conductance:  0.41677531508039983 f1score:  0.7196323921150773 precision:  0.5620513887444086 recall:  1.0
# outer: 1 number of node:  108  completed:  0.93  degree:  174.0
# conductance:  0.4398547435315479 f1score:  0.718070260931201 precision:  0.5601479075232402 recall:  1.0
# outer: 1 number of node:  74  completed:  0.94  degree:  163.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  104  completed:  0.95  degree:  154.0
# conductance:  0.4256546826453617 f1score:  0.7188664183076104 precision:  0.5611174576799253 recall:  1.0
# outer: 1 number of node:  128  completed:  0.96  degree:  170.0
# conductance:  0.4411492122335496 f1score:  0.7173552255980173 precision:  0.5592781726588917 recall:  1.0
# outer: 1 number of node:  99  completed:  0.97  degree:  157.0
# conductance:  0.42934293429342935 f1score:  0.8668029564396917 precision:  0.8841267804439882 recall:  0.8501449811832932
# outer: 1 number of node:  40  completed:  0.98  degree:  153.0
# conductance:  0.4339890357949049 f1score:  0.8652179374450445 precision:  0.8811000959385993 recall:  0.849898204701092
# outer: 1 number of node:  112  completed:  0.99  degree:  164.0
# conductance:  0.43591721300938424 f1score:  0.8048603897125949 precision:  0.821699447229721 recall:  0.7886976371151829
#
# Outer:  1  Elapsed time l1-reg. with rounding:  3.7357678413391113
# Outer:  1  Number of experiments:  512

# %% [markdown]
# ## Performance of l1-reg. PR (with rounding).

# %%
all_data = []
xlabels_ = []

print('Results for l1-reg with rounding')
sum_precision = 0
sum_recall = 0
sum_f1 = 0
sum_conductance = 0

info_ref_nodes = all_clusters
l_info_ref_nodes = len(info_ref_nodes)

for i in range(l_info_ref_nodes):
    temp_pre = []
    temp_rec = []
    temp_f1 = []
    temp_conductance = []
    
    for j in all_clusters[i]:
        temp_pre.append(precision_best_cond_acl[i,j])
        temp_rec.append(recall_best_cond_acl[i,j])
        temp_f1.append(f1score_best_cond_acl[i,j])
        temp_conductance.append(external_best_cond_acl[i,j])
    
    print('Feature:', i,'Precision', stat_.mean(temp_pre), 'Recall', stat_.mean(temp_rec), 'F1', stat_.mean(temp_f1), 'Cond.', stat_.mean(temp_conductance))
# Out:
# Results for l1-reg with rounding
# Feature: 0 Precision 0.7616010784971015 Recall 1.0 F1 0.8639590510056822 Cond. 0.4298763868141641
# Feature: 1 Precision 0.6756571753039263 Recall 0.9029434264914553 F1 0.7552208139349571 Cond. 0.43918351578430237

# %% [markdown]
# ## Function for seed set expansion using BFS

# %%
import queue
def seed_grow_bfs_steps(g,seeds,steps,vol_target,target_cluster):
    """
    grow the initial seed set through BFS until its size reaches 
    a given ratio of the total number of nodes.
    """
    Q = queue.Queue()
    visited = np.zeros(g._num_vertices)
    visited[seeds] = 1
    for s in seeds:
        Q.put(s)
    if isinstance(seeds,np.ndarray):
        seeds = seeds.tolist()
    else:
        seeds = list(seeds)
    for step in range(steps):
        for k in range(Q.qsize()):
            node = Q.get()
            si,ei = g.adjacency_matrix.indptr[node],g.adjacency_matrix.indptr[node+1]
            neighs = g.adjacency_matrix.indices[si:ei]
            for i in range(len(neighs)):
                if visited[neighs[i]] == 0:
                    visited[neighs[i]] = 1
                    seeds.append(neighs[i])
                    Q.put(neighs[i])
                    
                    vol_seeds = np.sum(g.d[seeds])
                    vol_target_intersection_input = np.sum(g.d[list(set(target_cluster).intersection(set(seeds)))])
                    sigma = vol_target_intersection_input/vol_target
                    
                    if sigma > 0.75 or vol_seeds > 0.25*g.vol_G:
                        break
                 
            vol_seeds = np.sum(g.d[seeds])
            vol_target_intersection_input = np.sum(g.d[list(set(target_cluster).intersection(set(seeds)))])
            sigma = vol_target_intersection_input/vol_target   
            
            if sigma > 0.75 or vol_seeds > 0.25*g.vol_G:
                break
               
        vol_seeds = np.sum(g.d[seeds])
        vol_target_intersection_input = np.sum(g.d[list(set(target_cluster).intersection(set(seeds)))])
        sigma = vol_target_intersection_input/vol_target
                
        if sigma > 0.75 or vol_seeds > 0.25*g.vol_G:
            break
    return seeds

# %% [markdown]
# ## Collect data for seed set expansion + FlowImprove, try a lot of parameters

# %%
nodes = {}
external_best_cond_flBFS = {}
external_best_pre_cond_flBFS = {}
vol_best_cond_flBFS = {}
vol_best_pre_flBFS = {}
size_clust_best_cond_flBFS = {}
size_clust_best_pre_flBFS = {}
f1score_best_cond_flBFS = {}
f1score_best_pre_flBFS = {}
true_positives_best_cond_flBFS = {}
true_positives_best_pre_flBFS = {}
precision_best_cond_flBFS = {}
precision_best_pre_flBFS = {}
recall_best_cond_flBFS = {}
recall_best_pre_flBFS = {}
cuts_best_cond_flBFS = {}
cuts_best_pre_flBFS = {}
cuts_flBFS_ALL = {}

ct_outer = 0

number_experiments = 0

for rr in all_clusters:
    
    how_many = int(len(rr))
    print(how_many)
    
    random.seed(4)
    
    nodes[ct_outer] = np.random.choice(rr, how_many, replace=False)
    
    n_step = 24
    
    vol_target = np.sum(g.d[rr])
    
    ct = 0
    
    start = time.time()
    
    for node in nodes[ct_outer]:
        ref_node = [node]
        
        max_precision = -1
        min_conduct = 100
                
        seeds = seed_grow_bfs_steps(g,[node],g._num_vertices,vol_target,rr)

        vol_input = np.sum(g.d[seeds])

        vol_graph_minus_input = np.sum(g.d[list(set(range(g._num_vertices)) - set(seeds))])

        vol_target_intersection_input = np.sum(g.d[list(set(rr).intersection(set(seeds)))])

        gamma = vol_input/vol_graph_minus_input
                
        sigma = max(vol_target_intersection_input/vol_target,gamma)
        
        delta = min(max((1/3)*(1.0/(1.0/sigma - 1)) - gamma,0),1)
                        
        S = flow_clustering(g,seeds,method="sl",delta=delta)[0]
        number_experiments += 1

        cuts_flBFS_ALL[ct_outer,node] = S

        size_clust_flBFS_ = len(S)

        cond_val_l1pr = g.compute_conductance(S)

        vol_ = sum(g.d[S])
        true_positives_flBFS_ = set(rr).intersection(S)
        if len(true_positives_flBFS_) == 0:
            true_positives_flBFS_ = set(ref_node)
            vol_ = g.d[ref_node][0]
        precision = sum(g.d[np.array(list(true_positives_flBFS_))])/vol_
        recall = sum(g.d[np.array(list(true_positives_flBFS_))])/sum(g.d[rr])
        f1_score_ = 2*(precision*recall)/(precision + recall)

        if f1_score_ >= max_precision:

            max_precision = f1_score_

            external_best_pre_cond_flBFS[ct_outer,node] = cond_val_l1pr
            vol_best_pre_flBFS[ct_outer,node] = vol_

            size_clust_best_pre_flBFS[ct_outer,node] = size_clust_flBFS_
            true_positives_best_pre_flBFS[ct_outer,node] = true_positives_flBFS_
            precision_best_pre_flBFS[ct_outer,node] = precision
            recall_best_pre_flBFS[ct_outer,node] = recall
            f1score_best_pre_flBFS[ct_outer,node] = f1_score_

            cuts_best_pre_flBFS[ct_outer,node] = S

        if cond_val_l1pr <= min_conduct:

            min_conduct = cond_val_l1pr

            external_best_cond_flBFS[ct_outer,node] = cond_val_l1pr
            vol_best_cond_flBFS[ct_outer,node] = vol_

            size_clust_best_cond_flBFS[ct_outer,node] = size_clust_flBFS_
            true_positives_best_cond_flBFS[ct_outer,node] = true_positives_flBFS_
            precision_best_cond_flBFS[ct_outer,node] = precision
            recall_best_cond_flBFS[ct_outer,node] = recall
            f1score_best_cond_flBFS[ct_outer,node] = f1_score_

            cuts_best_cond_flBFS[ct_outer,node] = S

        print('outer:', ct_outer, 'number of node: ',node, ' completed: ', ct/how_many, ' degree: ', g.d[node])
        print('conductance: ', external_best_cond_flBFS[ct_outer,node], 'f1score: ', f1score_best_cond_flBFS[ct_outer,node], 'precision: ', precision_best_cond_flBFS[ct_outer,node], 'recall: ', recall_best_cond_flBFS[ct_outer,node])
        ct += 1
    end = time.time()
    print(" ")
    print("Outer: ", ct_outer," Elapsed time BFS+SL: ", end - start)
    print("Outer: ", ct_outer," Number of experiments: ", number_experiments)
    print(" ")
    ct_outer += 1
# Out:
# 28
# outer: 0 number of node:  206  completed:  0.0  degree:  62.0
# conductance:  0.6493030080704328 f1score:  0.8657587548638133 precision:  0.979457079970653 recall:  0.7757117954677513
# outer: 0 number of node:  200  completed:  0.03571428571428571  degree:  45.0
# conductance:  0.6539325842696629 f1score:  0.8736910994764397 precision:  1.0 recall:  0.7757117954677513
# outer: 0 number of node:  160  completed:  0.07142857142857142  degree:  66.0
# conductance:  0.6539325842696629 f1score:  0.8736910994764397 precision:  1.0 recall:  0.7757117954677513
# outer: 0 number of node:  204  completed:  0.10714285714285714  degree:  52.0
# conductance:  0.6539325842696629 f1score:  0.8736910994764397 precision:  1.0 recall:  0.7757117954677513
# outer: 0 number of node:  214  completed:  0.14285714285714285  degree:  67.0
# conductance:  0.6570155902004454 f1score:  0.878096479791395 precision:  1.0 recall:  0.7826844857640907
# outer: 0 number of node:  218  completed:  0.17857142857142858  degree:  52.0
# conductance:  0.6531531531531531 f1score:  0.8725843432689159 precision:  1.0 recall:  0.7739686228936665
# outer: 0 number of node:  196  completed:  0.21428571428571427  degree:  67.0
# conductance:  0.6493030080704328 f1score:  0.8657587548638133 precision:  0.979457079970653 recall:  0.7757117954677513
# outer: 0 number of node:  201  completed:  0.25  degree:  63.0
# conductance:  0.6493030080704328 f1score:  0.8657587548638133 precision:  0.979457079970653 recall:  0.7757117954677513
# outer: 0 number of node:  159  completed:  0.2857142857142857  degree:  65.0
# conductance:  0.6539325842696629 f1score:  0.8736910994764397 precision:  1.0 recall:  0.7757117954677513
# outer: 0 number of node:  217  completed:  0.32142857142857145  degree:  67.0
# conductance:  0.6570155902004454 f1score:  0.878096479791395 precision:  1.0 recall:  0.7826844857640907
# outer: 0 number of node:  202  completed:  0.35714285714285715  degree:  54.0
# conductance:  0.6539325842696629 f1score:  0.8736910994764397 precision:  1.0 recall:  0.7757117954677513
# outer: 0 number of node:  156  completed:  0.39285714285714285  degree:  79.0
# conductance:  0.6539325842696629 f1score:  0.8736910994764397 precision:  1.0 recall:  0.7757117954677513
# outer: 0 number of node:  195  completed:  0.42857142857142855  degree:  76.0
# conductance:  0.6505061267980821 f1score:  0.7420789327404114 precision:  0.7112413425679276 recall:  0.7757117954677513
# outer: 0 number of node:  213  completed:  0.4642857142857143  degree:  63.0
# conductance:  0.649890590809628 f1score:  0.8686934023285898 precision:  0.9795769511305616 recall:  0.7803602556653109
# outer: 0 number of node:  207  completed:  0.5  degree:  63.0
# conductance:  0.6493030080704328 f1score:  0.8657587548638133 precision:  0.979457079970653 recall:  0.7757117954677513
# outer: 0 number of node:  211  completed:  0.5357142857142857  degree:  63.0
# conductance:  0.6493030080704328 f1score:  0.8657587548638133 precision:  0.979457079970653 recall:  0.7757117954677513
# outer: 0 number of node:  212  completed:  0.5714285714285714  degree:  55.0
# conductance:  0.6539325842696629 f1score:  0.8736910994764397 precision:  1.0 recall:  0.7757117954677513
# outer: 0 number of node:  205  completed:  0.6071428571428571  degree:  53.0
# conductance:  0.6539325842696629 f1score:  0.8736910994764397 precision:  1.0 recall:  0.7757117954677513
# outer: 0 number of node:  198  completed:  0.6428571428571429  degree:  52.0
# conductance:  0.6539325842696629 f1score:  0.8736910994764397 precision:  1.0 recall:  0.7757117954677513
# outer: 0 number of node:  215  completed:  0.6785714285714286  degree:  65.0
# conductance:  0.6565055762081784 f1score:  0.8773646444879322 precision:  1.0 recall:  0.7815223707147008
# outer: 0 number of node:  197  completed:  0.7142857142857143  degree:  52.0
# conductance:  0.6539325842696629 f1score:  0.8736910994764397 precision:  1.0 recall:  0.7757117954677513
# outer: 0 number of node:  208  completed:  0.75  degree:  63.0
# conductance:  0.6493030080704328 f1score:  0.8657587548638133 precision:  0.979457079970653 recall:  0.7757117954677513
# outer: 0 number of node:  210  completed:  0.7857142857142857  degree:  63.0
# conductance:  0.6493030080704328 f1score:  0.8657587548638133 precision:  0.979457079970653 recall:  0.7757117954677513
# outer: 0 number of node:  185  completed:  0.8214285714285714  degree:  63.0
# conductance:  0.6539325842696629 f1score:  0.8736910994764397 precision:  1.0 recall:  0.7757117954677513
# outer: 0 number of node:  203  completed:  0.8571428571428571  degree:  53.0
# conductance:  0.6539325842696629 f1score:  0.8736910994764397 precision:  1.0 recall:  0.7757117954677513
# outer: 0 number of node:  186  completed:  0.8928571428571429  degree:  63.0
# conductance:  0.6539325842696629 f1score:  0.8736910994764397 precision:  1.0 recall:  0.7757117954677513
# outer: 0 number of node:  209  completed:  0.9285714285714286  degree:  63.0
# conductance:  0.6493030080704328 f1score:  0.8657587548638133 precision:  0.979457079970653 recall:  0.7757117954677513
# outer: 0 number of node:  216  completed:  0.9642857142857143  degree:  72.0
# conductance:  0.658284023668639 f1score:  0.8799219004230394 precision:  1.0 recall:  0.7855897733875654
#
# Outer:  0  Elapsed time BFS+SL:  2.2957141399383545
# Outer:  0  Number of experiments:  28
#
# 100
# outer: 1 number of node:  58  completed:  0.0  degree:  162.0
# conductance:  0.736963781145646 f1score:  0.4315065638674724 precision:  0.6649113793989211 recall:  0.31939046208896293
# outer: 1 number of node:  103  completed:  0.01  degree:  150.0
# conductance:  0.7219549252975437 f1score:  0.4949599701331563 precision:  0.7553811091415549 recall:  0.36806712320315876
# outer: 1 number of node:  77  completed:  0.02  degree:  167.0
# conductance:  0.709068167604753 f1score:  0.400512312014543 precision:  0.606253908692933 recall:  0.2990314023073601
# outer: 1 number of node:  133  completed:  0.03  degree:  170.0
# conductance:  0.7083690724175958 f1score:  0.3848994665572425 precision:  0.5746844749417963 recall:  0.2893454253809612
# outer: 1 number of node:  52  completed:  0.04  degree:  159.0
# conductance:  0.733094262295082 f1score:  0.4716659033184828 precision:  0.7254098360655737 recall:  0.34943549879696467
# outer: 1 number of node:  102  completed:  0.05  degree:  150.0
# conductance:  0.7210652530607093 f1score:  0.508453505718548 precision:  0.7743279060961757 recall:  0.3784934295761614
# outer: 1 number of node:  91  completed:  0.06  degree:  155.0
# conductance:  0.7222011385199241 f1score:  0.4952309861491249 precision:  0.7553447185325743 recall:  0.3683755938059103
# outer: 1 number of node:  82  completed:  0.07  degree:  162.0
# conductance:  0.7329742208541746 f1score:  0.47154877947179874 precision:  0.7259202257278441 recall:  0.3491887223147634
# outer: 1 number of node:  95  completed:  0.08  degree:  148.0
# conductance:  0.7164066431806744 f1score:  0.5352485821914973 precision:  0.8134121791645696 recall:  0.3988524893577642
# outer: 1 number of node:  43  completed:  0.09  degree:  151.0
# conductance:  0.7202515723270441 f1score:  0.5092098182871808 precision:  0.7737106918238994 recall:  0.37948053550496635
# outer: 1 number of node:  106  completed:  0.1  degree:  160.0
# conductance:  0.7364717922476653 f1score:  0.444268708898693 precision:  0.6827427401816554 recall:  0.32926152137701276
# outer: 1 number of node:  49  completed:  0.11  degree:  160.0
# conductance:  0.7335688154408982 f1score:  0.4418296320848525 precision:  0.6726378201084899 recall:  0.32895305077426124
# outer: 1 number of node:  57  completed:  0.12  degree:  162.0
# conductance:  0.7192062897791089 f1score:  0.40004954173891505 precision:  0.6046424560089854 recall:  0.2989080140662595
# outer: 1 number of node:  44  completed:  0.13  degree:  153.0
# conductance:  0.7202515723270441 f1score:  0.5092098182871808 precision:  0.7737106918238994 recall:  0.37948053550496635
# outer: 1 number of node:  45  completed:  0.14  degree:  159.0
# conductance:  0.7302747668263171 f1score:  0.4554529263140455 precision:  0.6929669775649105 recall:  0.3391942747856129
# outer: 1 number of node:  101  completed:  0.15  degree:  150.0
# conductance:  0.7210652530607093 f1score:  0.508453505718548 precision:  0.7743279060961757 recall:  0.3784934295761614
# outer: 1 number of node:  67  completed:  0.16  degree:  166.0
# conductance:  0.7102953899394389 f1score:  0.37292181069958846 precision:  0.5600049437646768 recall:  0.27953606021346167
# outer: 1 number of node:  61  completed:  0.17  degree:  155.0
# conductance:  0.7294538029606943 f1score:  0.4573092118943647 precision:  0.7016334864726902 recall:  0.3391942747856129
# outer: 1 number of node:  114  completed:  0.18  degree:  163.0
# conductance:  0.7344770195877609 f1score:  0.44462947543713566 precision:  0.68365126104212 recall:  0.3294466037386637
# outer: 1 number of node:  119  completed:  0.19  degree:  178.0
# conductance:  0.7059480938780579 f1score:  0.34844612975022665 precision:  0.5248975537066931 recall:  0.26078104756616693
# outer: 1 number of node:  81  completed:  0.2  degree:  160.0
# conductance:  0.7371794871794872 f1score:  0.430838435586655 precision:  0.6630769230769231 recall:  0.31908199148621136
# outer: 1 number of node:  74  completed:  0.21  degree:  163.0
# conductance:  0.7101879327398615 f1score:  0.3727209120467548 precision:  0.559841740850643 recall:  0.27935097785181073
# outer: 1 number of node:  54  completed:  0.22  degree:  154.0
# conductance:  0.7321973550356052 f1score:  0.44298591783325725 precision:  0.6780264496439471 recall:  0.32895305077426124
# outer: 1 number of node:  118  completed:  0.23  degree:  175.0
# conductance:  0.7171692000996761 f1score:  0.4142768722921395 precision:  0.6254672314976327 recall:  0.309704485162564
# outer: 1 number of node:  107  completed:  0.24  degree:  161.0
# conductance:  0.7377259325727471 f1score:  0.43090379008746355 precision:  0.6631201128060505 recall:  0.31914368560676165
# outer: 1 number of node:  98  completed:  0.25  degree:  159.0
# conductance:  0.725515136097685 f1score:  0.47002617257280543 precision:  0.7195370134825744 recall:  0.34900363995311245
# outer: 1 number of node:  42  completed:  0.26  degree:  155.0
# conductance:  0.7202515723270441 f1score:  0.5092098182871808 precision:  0.7737106918238994 recall:  0.37948053550496635
# outer: 1 number of node:  65  completed:  0.27  degree:  165.0
# conductance:  0.7331145057442242 f1score:  0.42909241607956905 precision:  0.6535790935487944 recall:  0.31939046208896293
# outer: 1 number of node:  21  completed:  0.28  degree:  181.0
# conductance:  0.7077057139300386 f1score:  0.34799108984407223 precision:  0.5250840283829205 recall:  0.26022580048121413
# outer: 1 number of node:  117  completed:  0.29  degree:  163.0
# conductance:  0.7344770195877609 f1score:  0.44462947543713566 precision:  0.68365126104212 recall:  0.3294466037386637
# outer: 1 number of node:  113  completed:  0.3  degree:  163.0
# conductance:  0.7344770195877609 f1score:  0.44462947543713566 precision:  0.68365126104212 recall:  0.3294466037386637
# outer: 1 number of node:  84  completed:  0.31  degree:  157.0
# conductance:  0.725629931280224 f1score:  0.46993808950014543 precision:  0.7196487655892084 recall:  0.34888025171201187
# outer: 1 number of node:  80  completed:  0.32  degree:  166.0
# conductance:  0.7102953899394389 f1score:  0.37292181069958846 precision:  0.5600049437646768 recall:  0.27953606021346167
# outer: 1 number of node:  78  completed:  0.33  degree:  166.0
# conductance:  0.7102953899394389 f1score:  0.37292181069958846 precision:  0.5600049437646768 recall:  0.27953606021346167
# outer: 1 number of node:  47  completed:  0.34  degree:  159.0
# conductance:  0.732222934016656 f1score:  0.4440742899975015 precision:  0.6831518257527226 recall:  0.32895305077426124
# outer: 1 number of node:  88  completed:  0.35  degree:  161.0
# conductance:  0.712166172106825 f1score:  0.3984854097213647 precision:  0.5985410484668645 recall:  0.2986612375840582
# outer: 1 number of node:  94  completed:  0.36  degree:  167.0
# conductance:  0.7103311913000494 f1score:  0.3729887658944076 precision:  0.560059317844785 recall:  0.27959775433401196
# outer: 1 number of node:  70  completed:  0.37  degree:  169.0
# conductance:  0.7346600331674958 f1score:  0.44461077844311375 precision:  0.6819747416762342 recall:  0.32981676846196556
# outer: 1 number of node:  40  completed:  0.38  degree:  153.0
# conductance:  0.7202515723270441 f1score:  0.5092098182871808 precision:  0.7737106918238994 recall:  0.37948053550496635
# outer: 1 number of node:  93  completed:  0.39  degree:  161.0
# conductance:  0.712166172106825 f1score:  0.3984854097213647 precision:  0.5985410484668645 recall:  0.2986612375840582
# outer: 1 number of node:  96  completed:  0.4  degree:  168.0
# conductance:  0.7119464086341645 f1score:  0.3863205603625875 precision:  0.5815655625852871 recall:  0.28922203713986055
# outer: 1 number of node:  120  completed:  0.41  degree:  167.0
# conductance:  0.7070843019699009 f1score:  0.37174965138216715 precision:  0.5545087483176312 recall:  0.27959775433401196
# outer: 1 number of node:  121  completed:  0.42  degree:  167.0
# conductance:  0.7070843019699009 f1score:  0.37174965138216715 precision:  0.5545087483176312 recall:  0.27959775433401196
# outer: 1 number of node:  75  completed:  0.43  degree:  167.0
# conductance:  0.709068167604753 f1score:  0.400512312014543 precision:  0.606253908692933 recall:  0.2990314023073601
# outer: 1 number of node:  85  completed:  0.44  degree:  144.0
# conductance:  0.7201927955352613 f1score:  0.49474951230647907 precision:  0.7559614408929477 recall:  0.3676969584798569
# outer: 1 number of node:  122  completed:  0.45  degree:  166.0
# conductance:  0.7070484581497798 f1score:  0.3716828678068988 precision:  0.5544542339696524 recall:  0.27953606021346167
# outer: 1 number of node:  90  completed:  0.46  degree:  161.0
# conductance:  0.712166172106825 f1score:  0.3984854097213647 precision:  0.5985410484668645 recall:  0.2986612375840582
# outer: 1 number of node:  20  completed:  0.47  degree:  181.0
# conductance:  0.7074328544659588 f1score:  0.3605352275543074 precision:  0.5452841973766396 recall:  0.2692948362021099
# outer: 1 number of node:  131  completed:  0.48  degree:  168.0
# conductance:  0.7113146818519436 f1score:  0.38605015028616124 precision:  0.5803416687298837 recall:  0.28922203713986055
# outer: 1 number of node:  128  completed:  0.49  degree:  170.0
# conductance:  0.710438542310068 f1score:  0.37318959842001315 precision:  0.5602223594811612 recall:  0.2797828366956629
# outer: 1 number of node:  83  completed:  0.5  degree:  148.0
# conductance:  0.7273190621814475 f1score:  0.46938521012595086 precision:  0.7194189602446484 recall:  0.34832500462705906
# outer: 1 number of node:  48  completed:  0.51  degree:  159.0
# conductance:  0.732222934016656 f1score:  0.4440742899975015 precision:  0.6831518257527226 recall:  0.32895305077426124
# outer: 1 number of node:  109  completed:  0.52  degree:  174.0
# conductance:  0.7016129032258065 f1score:  0.34624687410322635 precision:  0.5160068426197458 recall:  0.2605342710839657
# outer: 1 number of node:  76  completed:  0.53  degree:  155.0
# conductance:  0.7288178913738019 f1score:  0.4566031455438129 precision:  0.7012140575079873 recall:  0.3385156394595595
# outer: 1 number of node:  41  completed:  0.54  degree:  153.0
# conductance:  0.7202515723270441 f1score:  0.5092098182871808 precision:  0.7737106918238994 recall:  0.37948053550496635
# outer: 1 number of node:  68  completed:  0.55  degree:  166.0
# conductance:  0.7102953899394389 f1score:  0.37292181069958846 precision:  0.5600049437646768 recall:  0.27953606021346167
# outer: 1 number of node:  127  completed:  0.56  degree:  157.0
# conductance:  0.732209020058771 f1score:  0.45673156931269765 precision:  0.7012904050083046 recall:  0.3386390277006601
# outer: 1 number of node:  62  completed:  0.57  degree:  160.0
# conductance:  0.7331145057442242 f1score:  0.42909241607956905 precision:  0.6535790935487944 recall:  0.31939046208896293
# outer: 1 number of node:  97  completed:  0.58  degree:  163.0
# conductance:  0.7357006975269499 f1score:  0.4157051548103262 precision:  0.6351299936588459 recall:  0.30896415571596025
# outer: 1 number of node:  110  completed:  0.59  degree:  167.0
# conductance:  0.7396100564391996 f1score:  0.43149343886690267 precision:  0.6643150333504361 recall:  0.3195138503300635
# outer: 1 number of node:  60  completed:  0.6  degree:  147.0
# conductance:  0.7247590055809234 f1score:  0.4968248038849458 precision:  0.7591324200913242 recall:  0.36923931149361466
# outer: 1 number of node:  46  completed:  0.61  degree:  161.0
# conductance:  0.7377132671250318 f1score:  0.4165731621161119 precision:  0.6381461675579323 recall:  0.30921093219816154
# outer: 1 number of node:  99  completed:  0.62  degree:  157.0
# conductance:  0.7254452926208651 f1score:  0.46989904025925455 precision:  0.7194656488549618 recall:  0.34888025171201187
# outer: 1 number of node:  100  completed:  0.63  degree:  163.0
# conductance:  0.7361288672973664 f1score:  0.4444259498148225 precision:  0.6826898491434416 recall:  0.3294466037386637
# outer: 1 number of node:  89  completed:  0.64  degree:  149.0
# conductance:  0.7251269035532995 f1score:  0.4826269251525592 precision:  0.7376903553299492 recall:  0.35862792275896105
# outer: 1 number of node:  64  completed:  0.65  degree:  167.0
# conductance:  0.709068167604753 f1score:  0.400512312014543 precision:  0.606253908692933 recall:  0.2990314023073601
# outer: 1 number of node:  50  completed:  0.66  degree:  171.0
# conductance:  0.7200050358806497 f1score:  0.37429612454455113 precision:  0.5690545134080323 recall:  0.2788574248874082
# outer: 1 number of node:  132  completed:  0.67  degree:  162.0
# conductance:  0.7111000991080277 f1score:  0.3856513323174499 precision:  0.5800297324083251 recall:  0.2888518724165587
# outer: 1 number of node:  111  completed:  0.68  degree:  158.0
# conductance:  0.7328784432650999 f1score:  0.42863657090743273 precision:  0.6532726813242355 recall:  0.3189586032451107
# outer: 1 number of node:  125  completed:  0.69  degree:  168.0
# conductance:  0.7071201370198189 f1score:  0.3718164294795554 precision:  0.5545632493271349 recall:  0.27965944845456225
# outer: 1 number of node:  104  completed:  0.7  degree:  154.0
# conductance:  0.7369771619194252 f1score:  0.4304461942257217 precision:  0.6628175519630485 recall:  0.3187118267629095
# outer: 1 number of node:  59  completed:  0.71  degree:  169.0
# conductance:  0.7083436494181728 f1score:  0.37221558858648657 precision:  0.5595444416934885 recall:  0.2788574248874082
# outer: 1 number of node:  115  completed:  0.72  degree:  171.0
# conductance:  0.7347486890906766 f1score:  0.4451473281171966 precision:  0.683974932855864 recall:  0.3299401567030662
# outer: 1 number of node:  31  completed:  0.73  degree:  166.0
# conductance:  0.7145381120646138 f1score:  0.3495628392657357 precision:  0.5323069156991419 recall:  0.26022580048121413
# outer: 1 number of node:  123  completed:  0.74  degree:  172.0
# conductance:  0.7170634426025178 f1score:  0.4140805546384946 precision:  0.6253271843450081 recall:  0.30951940280091306
# outer: 1 number of node:  71  completed:  0.75  degree:  166.0
# conductance:  0.7102953899394389 f1score:  0.37292181069958846 precision:  0.5600049437646768 recall:  0.27953606021346167
# outer: 1 number of node:  53  completed:  0.76  degree:  179.0
# conductance:  0.7077826725403817 f1score:  0.37078052581928556 precision:  0.5531081742535487 recall:  0.2788574248874082
# outer: 1 number of node:  63  completed:  0.77  degree:  165.0
# conductance:  0.7331145057442242 f1score:  0.42909241607956905 precision:  0.6535790935487944 recall:  0.31939046208896293
# outer: 1 number of node:  112  completed:  0.78  degree:  164.0
# conductance:  0.7256895894241769 f1score:  0.47034391094866257 precision:  0.7197152663022753 recall:  0.34931211055586403
# outer: 1 number of node:  130  completed:  0.79  degree:  170.0
# conductance:  0.7113861386138614 f1score:  0.38618304582321217 precision:  0.5804455445544554 recall:  0.2893454253809612
# outer: 1 number of node:  105  completed:  0.8  degree:  148.0
# conductance:  0.7193645990922845 f1score:  0.5080982560788699 precision:  0.7731971759959657 recall:  0.37837004133506075
# outer: 1 number of node:  126  completed:  0.81  degree:  167.0
# conductance:  0.7070843019699009 f1score:  0.37174965138216715 precision:  0.5545087483176312 recall:  0.27959775433401196
# outer: 1 number of node:  15  completed:  0.82  degree:  166.0
# conductance:  0.7175836860330896 f1score:  0.4718820294926268 precision:  0.7264332435552135 recall:  0.34943549879696467
# outer: 1 number of node:  108  completed:  0.83  degree:  174.0
# conductance:  0.7016129032258065 f1score:  0.34624687410322635 precision:  0.5160068426197458 recall:  0.2605342710839657
# outer: 1 number of node:  87  completed:  0.84  degree:  157.0
# conductance:  0.725629931280224 f1score:  0.46993808950014543 precision:  0.7196487655892084 recall:  0.34888025171201187
# outer: 1 number of node:  56  completed:  0.85  degree:  159.0
# conductance:  0.7330783938814531 f1score:  0.45713810592832793 precision:  0.7008285532186106 recall:  0.3391942747856129
# outer: 1 number of node:  79  completed:  0.86  degree:  155.0
# conductance:  0.7241467142129394 f1score:  0.4836872947924027 precision:  0.7410850738665308 recall:  0.3589980874822629
# outer: 1 number of node:  51  completed:  0.87  degree:  157.0
# conductance:  0.7289433384379785 f1score:  0.4573092118943647 precision:  0.7016334864726902 recall:  0.3391942747856129
# outer: 1 number of node:  86  completed:  0.88  degree:  162.0
# conductance:  0.7101270506969286 f1score:  0.3850962329330482 precision:  0.5775255951646725 recall:  0.2888518724165587
# outer: 1 number of node:  129  completed:  0.89  degree:  169.0
# conductance:  0.7104027674820855 f1score:  0.3731226597539399 precision:  0.5601680256980479 recall:  0.2797211425751126
# outer: 1 number of node:  72  completed:  0.9  degree:  166.0
# conductance:  0.7102953899394389 f1score:  0.37292181069958846 precision:  0.5600049437646768 recall:  0.27953606021346167
# outer: 1 number of node:  92  completed:  0.91  degree:  166.0
# conductance:  0.7102953899394389 f1score:  0.37292181069958846 precision:  0.5600049437646768 recall:  0.27953606021346167
# outer: 1 number of node:  69  completed:  0.92  degree:  152.0
# conductance:  0.7241204115330878 f1score:  0.4830163607673782 precision:  0.7387272958211609 recall:  0.358813005120612
# outer: 1 number of node:  124  completed:  0.93  degree:  172.0
# conductance:  0.715392303848076 f1score:  0.40077644240697147 precision:  0.6061969015492253 recall:  0.29933987291011166
# outer: 1 number of node:  116  completed:  0.94  degree:  156.0
# conductance:  0.7222362762458892 f1score:  0.4952933858594236 precision:  0.7553756640526182 recall:  0.36843728792646063
# outer: 1 number of node:  17  completed:  0.95  degree:  164.0
# conductance:  0.7153125401103838 f1score:  0.4581666666666666 precision:  0.7056860480041073 recall:  0.3391942747856129
# outer: 1 number of node:  73  completed:  0.96  degree:  161.0
# conductance:  0.7167919799498746 f1score:  0.4139071478771343 precision:  0.6273182957393484 recall:  0.30884076747485967
# outer: 1 number of node:  66  completed:  0.97  degree:  155.0
# conductance:  0.7294538029606943 f1score:  0.4573092118943647 precision:  0.7016334864726902 recall:  0.3391942747856129
# outer: 1 number of node:  55  completed:  0.98  degree:  159.0
# conductance:  0.732222934016656 f1score:  0.4440742899975015 precision:  0.6831518257527226 recall:  0.32895305077426124
# outer: 1 number of node:  28  completed:  0.99  degree:  166.0
# conductance:  0.7145381120646138 f1score:  0.3495628392657357 precision:  0.5323069156991419 recall:  0.26022580048121413
#
# Outer:  1  Elapsed time BFS+SL:  22.336305856704712
# Outer:  1  Number of experiments:  128

# %% [markdown]
# ## Performance of BFS+FlowImp.

# %%
all_data = []
xlabels_ = []

print('Results for BFS+SL')
sum_precision = 0
sum_recall = 0
sum_f1 = 0
sum_conductance = 0

info_ref_nodes = all_clusters
l_info_ref_nodes = len(info_ref_nodes)

for i in range(l_info_ref_nodes):
    temp_pre = []
    temp_rec = []
    temp_f1 = []
    temp_conductance = []
    
    for j in all_clusters[i]:
        temp_pre.append(precision_best_cond_flBFS[i,j])
        temp_rec.append(recall_best_cond_flBFS[i,j])
        temp_f1.append(f1score_best_cond_flBFS[i,j])
        temp_conductance.append(external_best_cond_flBFS[i,j])

    print('Feature:', i,'Precision', stat_.mean(temp_pre), 'Recall', stat_.mean(temp_rec), 'F1', stat_.mean(temp_f1), 'Cond.', stat_.mean(temp_conductance))
# Out:
# Results for BFS+SL
# Feature: 0 Precision 0.983088390480847 Recall 0.7768739105171412 F1 0.8671746612477108 Cond. 0.6527827968252733
# Feature: 1 Precision 0.6497698357105165 Recall 0.318420630513912 F1 0.4273749111275312 Cond. 0.7208422960860279

# %% [markdown]
# ## Collect data for APPR+SL

# %%
nodes = {}
external_best_cond_apprSL = {}
external_best_pre_cond_apprSL = {}
vol_best_cond_apprSL = {}
vol_best_pre_apprSL = {}
size_clust_best_cond_apprSL = {}
size_clust_best_pre_apprSL = {}
f1score_best_cond_apprSL = {}
f1score_best_pre_apprSL = {}
true_positives_best_cond_apprSL = {}
true_positives_best_pre_apprSL = {}
precision_best_cond_apprSL = {}
precision_best_pre_apprSL = {}
recall_best_cond_apprSL = {}
recall_best_pre_apprSL = {}
cuts_best_cond_apprSL = {}
cuts_best_pre_apprSL = {}
cuts_apprSL_ALL = {}

ct_outer = 0

number_experiments = 0

for rr in all_clusters:
    
    how_many = int(len(rr))
    print(how_many)
    
    random.seed(4)
    
    nodes[ct_outer] = np.random.choice(rr, how_many, replace=False)
    
    eigv, lambda_val = fiedler_local(g, rr)
    lambda_val = np.real(lambda_val)
    
    step = (2*lambda_val - lambda_val/2)/4
    
    a_list = np.arange(lambda_val/2,2*lambda_val,step)
    
    vol_target = np.sum(g.d[rr])
    
    ct = 0
    
    start = time.time()
    
    for node in nodes[ct_outer]:
        ref_node = [node]
        
        max_precision = -1
        min_conduct = 100
        
        ct_inner = 0
        for a in a_list:
            
            if ct_outer <= 1:
                rho = 0.15/np.sum(g.d[rr])
            else:
                rho = 0.2/np.sum(g.d[rr])
            
            output_pr_clustering = approximate_PageRank(g,ref_node,method = "acl", rho=rho, alpha=a, cpp = True, normalize=True,normalized_objective=True)
            number_experiments += 1
            
            output_pr_sc = sweep_cut(g,output_pr_clustering,cpp=True)
            
            S = output_pr_sc[0]
            
            vol_input = np.sum(g.d[S])

            vol_graph_minus_input = np.sum(g.d[list(set(range(g._num_vertices)) - set(S))])

            vol_target_intersection_input = np.sum(g.d[list(set(rr).intersection(set(S)))])

            gamma = vol_input/vol_graph_minus_input

            sigma = max(vol_target_intersection_input/vol_target,gamma)

            delta = min(max((1/3)*(1.0/(1.0/sigma - 1)) - gamma,0),1)

            S = flow_clustering(g,S,method="sl",delta=delta)[0]
            
            cuts_apprSL_ALL[ct_outer,node,ct_inner] = S
            
            size_clust_apprSL_ = len(S)
            
            cond_val_l1pr = g.compute_conductance(S)
            
            vol_ = sum(g.d[S])
            true_positives_apprSL_ = set(rr).intersection(S)
            if len(true_positives_apprSL_) == 0:
                true_positives_apprSL_ = set(ref_node)
                vol_ = g.d[ref_node][0]
            precision = sum(g.d[np.array(list(true_positives_apprSL_))])/vol_
            recall = sum(g.d[np.array(list(true_positives_apprSL_))])/sum(g.d[rr])
            f1_score_ = 2*(precision*recall)/(precision + recall)
            
            if f1_score_ >= max_precision:
                
                max_precision = f1_score_
                
                external_best_pre_cond_apprSL[ct_outer,node] = cond_val_l1pr
                vol_best_pre_apprSL[ct_outer,node] = vol_
                
                size_clust_best_pre_apprSL[ct_outer,node] = size_clust_apprSL_
                true_positives_best_pre_apprSL[ct_outer,node] = true_positives_apprSL_
                precision_best_pre_apprSL[ct_outer,node] = precision
                recall_best_pre_apprSL[ct_outer,node] = recall
                f1score_best_pre_apprSL[ct_outer,node] = f1_score_
                
                cuts_best_pre_apprSL[ct_outer,node] = S
        
            if cond_val_l1pr <= min_conduct:
                
                min_conduct = cond_val_l1pr
                
                external_best_cond_apprSL[ct_outer,node] = cond_val_l1pr
                vol_best_cond_apprSL[ct_outer,node] = vol_
                
                size_clust_best_cond_apprSL[ct_outer,node] = size_clust_apprSL_
                true_positives_best_cond_apprSL[ct_outer,node] = true_positives_apprSL_
                precision_best_cond_apprSL[ct_outer,node] = precision
                recall_best_cond_apprSL[ct_outer,node] = recall
                f1score_best_cond_apprSL[ct_outer,node] = f1_score_
                
                cuts_best_cond_apprSL[ct_outer,node] = S

        print('outer:', ct_outer, 'number of node: ',node, ' completed: ', ct/how_many, ' degree: ', g.d[node])
        print('conductance: ', external_best_cond_apprSL[ct_outer,node], 'f1score: ', f1score_best_cond_apprSL[ct_outer,node], 'precision: ', precision_best_cond_apprSL[ct_outer,node], 'recall: ', recall_best_cond_apprSL[ct_outer,node])
        ct += 1
    end = time.time()
    print(" ")
    print("Outer: ", ct_outer," Elapsed time APPR+SL with rounding: ", end - start)
    print("Outer: ", ct_outer," Number of experiments: ", number_experiments)
    print(" ")
    ct_outer += 1
# Out:
# 28
# outer: 0 number of node:  160  completed:  0.0  degree:  66.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# /usr/local/Cellar/ipython/7.1.1/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:77: RuntimeWarning:
#
# divide by zero encountered in double_scalars
# outer: 0 number of node:  201  completed:  0.03571428571428571  degree:  63.0
# conductance:  0.4411492122335496 f1score:  0.8873420984789894 precision:  0.7974976830398517 recall:  1.0
# outer: 0 number of node:  200  completed:  0.07142857142857142  degree:  45.0
# conductance:  0.4935930292157868 f1score:  0.9373638344226579 precision:  0.8821117375704767 recall:  1.0
# outer: 0 number of node:  213  completed:  0.10714285714285714  degree:  63.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  216  completed:  0.14285714285714285  degree:  72.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  203  completed:  0.17857142857142858  degree:  53.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  208  completed:  0.21428571428571427  degree:  63.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  217  completed:  0.25  degree:  67.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  210  completed:  0.2857142857142857  degree:  63.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  202  completed:  0.32142857142857145  degree:  54.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  198  completed:  0.35714285714285715  degree:  52.0
# conductance:  0.4329023629068212 f1score:  0.8683148335015136 precision:  0.7672759696834597 recall:  1.0
# outer: 0 number of node:  186  completed:  0.39285714285714285  degree:  63.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  215  completed:  0.42857142857142855  degree:  65.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  185  completed:  0.4642857142857143  degree:  63.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  195  completed:  0.5  degree:  76.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  214  completed:  0.5357142857142857  degree:  67.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  209  completed:  0.5714285714285714  degree:  63.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  207  completed:  0.6071428571428571  degree:  63.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  159  completed:  0.6428571428571429  degree:  65.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  204  completed:  0.6785714285714286  degree:  52.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  197  completed:  0.7142857142857143  degree:  52.0
# conductance:  0.4329023629068212 f1score:  0.8683148335015136 precision:  0.7672759696834597 recall:  1.0
# outer: 0 number of node:  156  completed:  0.75  degree:  79.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  196  completed:  0.7857142857142857  degree:  67.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  211  completed:  0.8214285714285714  degree:  63.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  212  completed:  0.8571428571428571  degree:  55.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  206  completed:  0.8928571428571429  degree:  62.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  205  completed:  0.9285714285714286  degree:  53.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  218  completed:  0.9642857142857143  degree:  52.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
#
# Outer:  0  Elapsed time APPR+SL with rounding:  3.7979347705841064
# Outer:  0  Number of experiments:  112
#
# 100
# outer: 1 number of node:  121  completed:  0.0  degree:  167.0
# conductance:  0.4677027683341428 f1score:  0.020395701025891548 precision:  1.0 recall:  0.01030291813190203
# outer: 1 number of node:  86  completed:  0.01  degree:  162.0
# conductance:  0.4126234435379991 f1score:  0.019791094007696537 precision:  1.0 recall:  0.009994447529150472
# outer: 1 number of node:  87  completed:  0.02  degree:  157.0
# conductance:  0.42488888888888887 f1score:  0.019186117560796776 precision:  1.0 recall:  0.009685976926398915
# outer: 1 number of node:  48  completed:  0.03  degree:  159.0
# conductance:  0.4126234435379991 f1score:  0.019428152492668622 precision:  1.0 recall:  0.009809365167499537
# outer: 1 number of node:  72  completed:  0.04  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.020274809160305347 precision:  1.0 recall:  0.010241224011351718
# outer: 1 number of node:  31  completed:  0.05  degree:  166.0
# conductance:  0.4126234435379991 f1score:  0.020274809160305347 precision:  1.0 recall:  0.010241224011351718
# outer: 1 number of node:  67  completed:  0.06  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.020274809160305347 precision:  1.0 recall:  0.010241224011351718
# outer: 1 number of node:  77  completed:  0.07  degree:  167.0
# conductance:  0.4256546826453617 f1score:  0.020395701025891548 precision:  1.0 recall:  0.01030291813190203
# outer: 1 number of node:  71  completed:  0.08  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.020274809160305347 precision:  1.0 recall:  0.010241224011351718
# outer: 1 number of node:  70  completed:  0.09  degree:  169.0
# conductance:  0.4606317160534028 f1score:  0.6479533645925739 precision:  0.665971996092478 recall:  0.6308840767474859
# outer: 1 number of node:  92  completed:  0.1  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.020274809160305347 precision:  1.0 recall:  0.010241224011351718
# outer: 1 number of node:  95  completed:  0.11  degree:  148.0
# conductance:  0.4126234435379991 f1score:  0.018096227914654275 precision:  1.0 recall:  0.00913072984144611
# outer: 1 number of node:  106  completed:  0.12  degree:  160.0
# conductance:  0.4126234435379991 f1score:  0.019549147779338995 precision:  1.0 recall:  0.00987105928804985
# outer: 1 number of node:  28  completed:  0.13  degree:  166.0
# conductance:  0.4126234435379991 f1score:  0.020274809160305347 precision:  1.0 recall:  0.010241224011351718
# outer: 1 number of node:  78  completed:  0.14  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.020274809160305347 precision:  1.0 recall:  0.010241224011351718
# outer: 1 number of node:  45  completed:  0.15  degree:  159.0
# conductance:  0.4411492122335496 f1score:  0.019428152492668622 precision:  1.0 recall:  0.009809365167499537
# outer: 1 number of node:  125  completed:  0.16  degree:  168.0
# conductance:  0.4703005802960162 f1score:  0.6167501426488303 precision:  0.6342831062137315 recall:  0.6001604047134308
# outer: 1 number of node:  17  completed:  0.17  degree:  164.0
# conductance:  0.46035487461533425 f1score:  0.6905533320627659 precision:  0.7117134813068814 recall:  0.6706150903818866
# outer: 1 number of node:  65  completed:  0.18  degree:  165.0
# conductance:  0.4558190347664032 f1score:  0.6713251495121184 precision:  0.6853030010924748 recall:  0.6579061015485225
# outer: 1 number of node:  132  completed:  0.19  degree:  162.0
# conductance:  0.4126234435379991 f1score:  0.019791094007696537 precision:  1.0 recall:  0.009994447529150472
# outer: 1 number of node:  89  completed:  0.2  degree:  149.0
# conductance:  0.4355987055016181 f1score:  0.7679332891121009 precision:  0.7867961165048544 recall:  0.7499537294095873
# outer: 1 number of node:  43  completed:  0.21  degree:  151.0
# conductance:  0.4375885611232771 f1score:  0.7650858673389003 precision:  0.7819142084245781 recall:  0.7489666234807822
# outer: 1 number of node:  57  completed:  0.22  degree:  162.0
# conductance:  0.4126234435379991 f1score:  0.019791094007696537 precision:  1.0 recall:  0.009994447529150472
# outer: 1 number of node:  96  completed:  0.23  degree:  168.0
# conductance:  0.4126234435379991 f1score:  0.020516578127862246 precision:  1.0 recall:  0.01036461225245234
# outer: 1 number of node:  127  completed:  0.24  degree:  157.0
# conductance:  0.4473563218390805 f1score:  0.019186117560796776 precision:  1.0 recall:  0.009685976926398915
# outer: 1 number of node:  68  completed:  0.25  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.020274809160305347 precision:  1.0 recall:  0.010241224011351718
# outer: 1 number of node:  101  completed:  0.26  degree:  150.0
# conductance:  0.4126234435379991 f1score:  0.018338529249954154 precision:  1.0 recall:  0.009254118082546734
# outer: 1 number of node:  119  completed:  0.27  degree:  178.0
# conductance:  0.4794823437601613 f1score:  0.5900715506870133 precision:  0.6060349873187227 recall:  0.5749275094083534
# outer: 1 number of node:  133  completed:  0.28  degree:  170.0
# conductance:  0.4623614082863256 f1score:  0.627718765806778 precision:  0.6437139337353304 recall:  0.6124992288234932
# outer: 1 number of node:  131  completed:  0.29  degree:  168.0
# conductance:  0.4411492122335496 f1score:  0.020516578127862246 precision:  1.0 recall:  0.01036461225245234
# outer: 1 number of node:  64  completed:  0.3  degree:  167.0
# conductance:  0.4256546826453617 f1score:  0.020395701025891548 precision:  1.0 recall:  0.01030291813190203
# outer: 1 number of node:  129  completed:  0.31  degree:  169.0
# conductance:  0.4411492122335496 f1score:  0.020637440468921724 precision:  1.0 recall:  0.010426306373002653
# outer: 1 number of node:  112  completed:  0.32  degree:  164.0
# conductance:  0.4441444915798946 f1score:  0.6931721597884597 precision:  0.7076745082915542 recall:  0.6792522672589302
# outer: 1 number of node:  44  completed:  0.33  degree:  153.0
# conductance:  0.4392474862147259 f1score:  0.75727295724766 precision:  0.7767758676613687 recall:  0.7387253994694306
# outer: 1 number of node:  82  completed:  0.34  degree:  162.0
# conductance:  0.449723036819811 f1score:  0.6979146859352222 precision:  0.717562724014337 recall:  0.6793139613794805
# outer: 1 number of node:  58  completed:  0.35  degree:  162.0
# conductance:  0.45161499967505037 f1score:  0.6965438663121915 precision:  0.7151491518814583 recall:  0.6788821025356283
# outer: 1 number of node:  109  completed:  0.36  degree:  174.0
# conductance:  0.4126234435379991 f1score:  0.021241530855154733 precision:  1.0 recall:  0.01073477697575421
# outer: 1 number of node:  40  completed:  0.37  degree:  153.0
# conductance:  0.44141565285277473 f1score:  0.7376820772640911 precision:  0.7577906447205777 recall:  0.718613116170029
# outer: 1 number of node:  90  completed:  0.38  degree:  161.0
# conductance:  0.4126234435379991 f1score:  0.019670128283445325 precision:  1.0 recall:  0.00993275340860016
# outer: 1 number of node:  47  completed:  0.39  degree:  159.0
# conductance:  0.4126234435379991 f1score:  0.019428152492668622 precision:  1.0 recall:  0.009809365167499537
# outer: 1 number of node:  15  completed:  0.4  degree:  166.0
# conductance:  0.4514608859566447 f1score:  0.020274809160305347 precision:  1.0 recall:  0.010241224011351718
# outer: 1 number of node:  91  completed:  0.41  degree:  155.0
# conductance:  0.43678310740354537 f1score:  0.8658447691186257 precision:  0.8902502606882169 recall:  0.8427416867172558
# outer: 1 number of node:  116  completed:  0.42  degree:  156.0
# conductance:  0.4356136173498938 f1score:  0.7442988534710848 precision:  0.7603449385417337 recall:  0.728916034301931
# outer: 1 number of node:  104  completed:  0.43  degree:  154.0
# conductance:  0.4256546826453617 f1score:  0.018822954225997682 precision:  1.0 recall:  0.00950089456474798
# outer: 1 number of node:  50  completed:  0.44  degree:  171.0
# conductance:  0.4126234435379991 f1score:  0.020879120879120878 precision:  1.0 recall:  0.010549694614103275
# outer: 1 number of node:  108  completed:  0.45  degree:  174.0
# conductance:  0.4126234435379991 f1score:  0.021241530855154733 precision:  1.0 recall:  0.01073477697575421
# outer: 1 number of node:  102  completed:  0.46  degree:  150.0
# conductance:  0.4126234435379991 f1score:  0.018338529249954154 precision:  1.0 recall:  0.009254118082546734
# outer: 1 number of node:  114  completed:  0.47  degree:  163.0
# conductance:  0.463987919374959 f1score:  0.682379134860051 precision:  0.7042873087781498 recall:  0.6617928311431921
# outer: 1 number of node:  49  completed:  0.48  degree:  160.0
# conductance:  0.4126234435379991 f1score:  0.019549147779338995 precision:  1.0 recall:  0.00987105928804985
# outer: 1 number of node:  99  completed:  0.49  degree:  157.0
# conductance:  0.43321884518177695 f1score:  0.7676359039190898 precision:  0.7869872334910245 recall:  0.7492133999629835
# outer: 1 number of node:  105  completed:  0.5  degree:  148.0
# conductance:  0.4126234435379991 f1score:  0.018096227914654275 precision:  1.0 recall:  0.00913072984144611
# outer: 1 number of node:  98  completed:  0.51  degree:  159.0
# conductance:  0.43724066390041494 f1score:  0.7575633041444062 precision:  0.776841286307054 recall:  0.7392189524338331
# outer: 1 number of node:  46  completed:  0.52  degree:  161.0
# conductance:  0.4126234435379991 f1score:  0.019670128283445325 precision:  1.0 recall:  0.00993275340860016
# outer: 1 number of node:  79  completed:  0.53  degree:  155.0
# conductance:  0.4126234435379991 f1score:  0.018944023466145196 precision:  1.0 recall:  0.00956258868529829
# outer: 1 number of node:  128  completed:  0.54  degree:  170.0
# conductance:  0.4411492122335496 f1score:  0.020758288051773613 precision:  1.0 recall:  0.010488000493552965
# outer: 1 number of node:  111  completed:  0.55  degree:  158.0
# conductance:  0.4497060533626203 f1score:  0.7885634940671548 precision:  0.8071580851476193 recall:  0.7708063421555925
# outer: 1 number of node:  93  completed:  0.56  degree:  161.0
# conductance:  0.4126234435379991 f1score:  0.019670128283445325 precision:  1.0 recall:  0.00993275340860016
# outer: 1 number of node:  124  completed:  0.57  degree:  172.0
# conductance:  0.4603174603174603 f1score:  0.020999938953665833 precision:  1.0 recall:  0.010611388734653587
# outer: 1 number of node:  115  completed:  0.58  degree:  171.0
# conductance:  0.48318271386831557 f1score:  0.6938498350902154 precision:  0.7290208602296664 recall:  0.6619162193842927
# outer: 1 number of node:  41  completed:  0.59  degree:  153.0
# conductance:  0.44141565285277473 f1score:  0.7376820772640911 precision:  0.7577906447205777 recall:  0.718613116170029
# outer: 1 number of node:  113  completed:  0.6  degree:  163.0
# conductance:  0.463987919374959 f1score:  0.682379134860051 precision:  0.7042873087781498 recall:  0.6617928311431921
# outer: 1 number of node:  118  completed:  0.61  degree:  175.0
# conductance:  0.4791948035243424 f1score:  0.6154088050314467 precision:  0.6276056699377847 recall:  0.6036769695847986
# outer: 1 number of node:  61  completed:  0.62  degree:  155.0
# conductance:  0.4220264317180617 f1score:  0.018944023466145196 precision:  1.0 recall:  0.00956258868529829
# outer: 1 number of node:  120  completed:  0.63  degree:  167.0
# conductance:  0.4677027683341428 f1score:  0.020395701025891548 precision:  1.0 recall:  0.01030291813190203
# outer: 1 number of node:  60  completed:  0.64  degree:  147.0
# conductance:  0.43603370058327934 f1score:  0.8117829261354657 precision:  0.8322747893713545 recall:  0.792275896107101
# outer: 1 number of node:  126  completed:  0.65  degree:  167.0
# conductance:  0.4677027683341428 f1score:  0.020395701025891548 precision:  1.0 recall:  0.01030291813190203
# outer: 1 number of node:  69  completed:  0.66  degree:  152.0
# conductance:  0.4126234435379991 f1score:  0.01858077134649471 precision:  1.0 recall:  0.009377506323647356
# outer: 1 number of node:  52  completed:  0.67  degree:  159.0
# conductance:  0.4385805277525023 f1score:  0.019428152492668622 precision:  1.0 recall:  0.009809365167499537
# outer: 1 number of node:  130  completed:  0.68  degree:  170.0
# conductance:  0.4588311268969971 f1score:  0.6363980564144632 precision:  0.6512754278333871 recall:  0.622185205749892
# outer: 1 number of node:  83  completed:  0.69  degree:  148.0
# conductance:  0.4126234435379991 f1score:  0.018096227914654275 precision:  1.0 recall:  0.00913072984144611
# outer: 1 number of node:  122  completed:  0.7  degree:  166.0
# conductance:  0.4677027683341428 f1score:  0.020274809160305347 precision:  1.0 recall:  0.010241224011351718
# outer: 1 number of node:  80  completed:  0.71  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.020274809160305347 precision:  1.0 recall:  0.010241224011351718
# outer: 1 number of node:  56  completed:  0.72  degree:  159.0
# conductance:  0.4411492122335496 f1score:  0.019428152492668622 precision:  1.0 recall:  0.009809365167499537
# outer: 1 number of node:  85  completed:  0.73  degree:  144.0
# conductance:  0.4126234435379991 f1score:  0.017611447440836547 precision:  1.0 recall:  0.008883953359244865
# outer: 1 number of node:  107  completed:  0.74  degree:  161.0
# conductance:  0.43742335248176595 f1score:  0.7252539271970223 precision:  0.7420125217840315 recall:  0.7092356098463817
# outer: 1 number of node:  63  completed:  0.75  degree:  165.0
# conductance:  0.4558190347664032 f1score:  0.6713251495121184 precision:  0.6853030010924748 recall:  0.6579061015485225
# outer: 1 number of node:  53  completed:  0.76  degree:  179.0
# conductance:  0.4877450980392157 f1score:  0.5941906107709216 precision:  0.6050780250703505 recall:  0.5836880745264976
# outer: 1 number of node:  51  completed:  0.77  degree:  157.0
# conductance:  0.4126234435379991 f1score:  0.019186117560796776 precision:  1.0 recall:  0.009685976926398915
# outer: 1 number of node:  100  completed:  0.78  degree:  163.0
# conductance:  0.4440765985069782 f1score:  0.7082937938887834 precision:  0.7267770204479065 recall:  0.6907273736812882
# outer: 1 number of node:  84  completed:  0.79  degree:  157.0
# conductance:  0.42488888888888887 f1score:  0.019186117560796776 precision:  1.0 recall:  0.009685976926398915
# outer: 1 number of node:  117  completed:  0.8  degree:  163.0
# conductance:  0.463987919374959 f1score:  0.682379134860051 precision:  0.7042873087781498 recall:  0.6617928311431921
# outer: 1 number of node:  97  completed:  0.81  degree:  163.0
# conductance:  0.42488888888888887 f1score:  0.01991204495480088 precision:  1.0 recall:  0.010056141649700784
# outer: 1 number of node:  21  completed:  0.82  degree:  181.0
# conductance:  0.492986878676233 f1score:  0.5864859777903255 precision:  0.5965919969366265 recall:  0.5767166389043125
# outer: 1 number of node:  103  completed:  0.83  degree:  150.0
# conductance:  0.4126234435379991 f1score:  0.018338529249954154 precision:  1.0 recall:  0.009254118082546734
# outer: 1 number of node:  76  completed:  0.84  degree:  155.0
# conductance:  0.4220264317180617 f1score:  0.018944023466145196 precision:  1.0 recall:  0.00956258868529829
# outer: 1 number of node:  123  completed:  0.85  degree:  172.0
# conductance:  0.4799845041322314 f1score:  0.6168407104773322 precision:  0.631198347107438 recall:  0.6031217224998457
# outer: 1 number of node:  75  completed:  0.86  degree:  167.0
# conductance:  0.4256546826453617 f1score:  0.020395701025891548 precision:  1.0 recall:  0.01030291813190203
# outer: 1 number of node:  66  completed:  0.87  degree:  155.0
# conductance:  0.4220264317180617 f1score:  0.018944023466145196 precision:  1.0 recall:  0.00956258868529829
# outer: 1 number of node:  20  completed:  0.88  degree:  181.0
# conductance:  0.490449148167269 f1score:  0.5769436997319034 precision:  0.590216830149716 recall:  0.5642544265531495
# outer: 1 number of node:  110  completed:  0.89  degree:  167.0
# conductance:  0.41677531508039983 f1score:  0.020395701025891548 precision:  1.0 recall:  0.01030291813190203
# outer: 1 number of node:  81  completed:  0.9  degree:  160.0
# conductance:  0.41677531508039983 f1score:  0.019549147779338995 precision:  1.0 recall:  0.00987105928804985
# outer: 1 number of node:  59  completed:  0.91  degree:  169.0
# conductance:  0.47048066875653083 f1score:  0.6419847086069604 precision:  0.6607889237199582 recall:  0.6242211117280523
# outer: 1 number of node:  73  completed:  0.92  degree:  161.0
# conductance:  0.4383249886208466 f1score:  0.019670128283445325 precision:  1.0 recall:  0.00993275340860016
# outer: 1 number of node:  88  completed:  0.93  degree:  161.0
# conductance:  0.4126234435379991 f1score:  0.019670128283445325 precision:  1.0 recall:  0.00993275340860016
# outer: 1 number of node:  54  completed:  0.94  degree:  154.0
# conductance:  0.4126234435379991 f1score:  0.018822954225997682 precision:  1.0 recall:  0.00950089456474798
# outer: 1 number of node:  74  completed:  0.95  degree:  163.0
# conductance:  0.4411492122335496 f1score:  0.01991204495480088 precision:  1.0 recall:  0.010056141649700784
# outer: 1 number of node:  42  completed:  0.96  degree:  155.0
# conductance:  0.4441568525947975 f1score:  0.8311909800082116 precision:  0.8514947586385402 recall:  0.8118329323215497
# outer: 1 number of node:  62  completed:  0.97  degree:  160.0
# conductance:  0.4436391872654329 f1score:  0.7250734295550012 precision:  0.7427850394719814 recall:  0.7081868097970263
# outer: 1 number of node:  94  completed:  0.98  degree:  167.0
# conductance:  0.45842985842985845 f1score:  0.6454376515795773 precision:  0.6593307593307594 recall:  0.6321179591584922
# outer: 1 number of node:  55  completed:  0.99  degree:  159.0
# conductance:  0.4126234435379991 f1score:  0.019428152492668622 precision:  1.0 recall:  0.009809365167499537
#
# Outer:  1  Elapsed time APPR+SL with rounding:  113.75794005393982
# Outer:  1  Number of experiments:  512

# %% [markdown]
# ## Performance of APPR+SL

# %%
all_data = []
xlabels_ = []

print('Results for APPR+SL')
sum_precision = 0
sum_recall = 0
sum_f1 = 0
sum_conductance = 0

info_ref_nodes = all_clusters
l_info_ref_nodes = len(info_ref_nodes)

for i in range(l_info_ref_nodes):
    temp_pre = []
    temp_rec = []
    temp_f1 = []
    temp_conductance = []
    
    for j in all_clusters[i]:
        temp_pre.append(precision_best_cond_apprSL[i,j])
        temp_rec.append(recall_best_cond_apprSL[i,j])
        temp_f1.append(f1score_best_cond_apprSL[i,j])
        temp_conductance.append(external_best_cond_apprSL[i,j])

    print('Feature:', i,'Precision', stat_.mean(temp_pre), 'Recall', stat_.mean(temp_rec), 'F1', stat_.mean(temp_f1), 'Cond.', stat_.mean(temp_conductance))
# Out:
# Results for APPR+SL
# Feature: 0 Precision 0.7683214659749378 Recall 1.0 F1 0.8685372472776756 Cond. 0.427663502821075
# Feature: 1 Precision 0.89414672073611 Recall 0.2574433956443951 F1 0.2699017442541204 Cond. 0.4376144431843467

# %% [markdown]
# ## Collect data for L1+SL

# %%
nodes = {}
external_best_cond_l1SL = {}
external_best_pre_cond_l1SL = {}
vol_best_cond_l1SL = {}
vol_best_pre_l1SL = {}
size_clust_best_cond_l1SL = {}
size_clust_best_pre_l1SL = {}
f1score_best_cond_l1SL = {}
f1score_best_pre_l1SL = {}
true_positives_best_cond_l1SL = {}
true_positives_best_pre_l1SL = {}
precision_best_cond_l1SL = {}
precision_best_pre_l1SL = {}
recall_best_cond_l1SL = {}
recall_best_pre_l1SL = {}
cuts_best_cond_l1SL = {}
cuts_best_pre_l1SL = {}
cuts_l1SL_ALL = {}

ct_outer = 0

number_experiments = 0

for rr in all_clusters:
    
    how_many = int(len(rr))
    print(how_many)
    
    random.seed(4)
    
    nodes[ct_outer] = np.random.choice(rr, how_many, replace=False)
    
    eigv, lambda_val = fiedler_local(g, rr)
    lambda_val = np.real(lambda_val)
    
    step = (2*lambda_val - lambda_val/2)/4
    
    a_list = np.arange(lambda_val/2,2*lambda_val,step)
    
    vol_target = np.sum(g.d[rr])
    
    ct = 0
    
    start = time.time()
    
    for node in nodes[ct_outer]:
        ref_node = [node]
        
        max_precision = -1
        min_conduct = 100
        
        ct_inner = 0
        for a in a_list:
            
            if ct_outer <= 1:
                rho = 0.15/np.sum(g.d[rr])
            else:
                rho = 0.2/np.sum(g.d[rr])
            
            output_pr_clustering = approximate_PageRank(g,ref_node,method = "l1reg-rand", epsilon=1.0e-2, rho=rho, alpha=a, cpp = True, normalize=True,normalized_objective=True)
            number_experiments += 1
            
            output_pr_sc = sweep_cut(g,output_pr_clustering,cpp=True)
            
            S = output_pr_sc[0]
            
            vol_input = np.sum(g.d[S])

            vol_graph_minus_input = np.sum(g.d[list(set(range(g._num_vertices)) - set(S))])

            vol_target_intersection_input = np.sum(g.d[list(set(rr).intersection(set(S)))])

            gamma = vol_input/vol_graph_minus_input

            sigma = max(vol_target_intersection_input/vol_target,gamma)

            delta = min(max((1/3)*(1.0/(1.0/sigma - 1)) - gamma,0),1)

            S = flow_clustering(g,S,method="sl",delta=delta)[0]
            
            cuts_l1SL_ALL[ct_outer,node,ct_inner] = S
            
            size_clust_l1SL_ = len(S)
            
            cond_val_l1pr = g.compute_conductance(S)
            
            vol_ = sum(g.d[S])
            true_positives_l1SL_ = set(rr).intersection(S)
            if len(true_positives_l1SL_) == 0:
                true_positives_l1SL_ = set(ref_node)
                vol_ = g.d[ref_node][0]
            precision = sum(g.d[np.array(list(true_positives_l1SL_))])/vol_
            recall = sum(g.d[np.array(list(true_positives_l1SL_))])/sum(g.d[rr])
            f1_score_ = 2*(precision*recall)/(precision + recall)
            
            if f1_score_ >= max_precision:
                
                max_precision = f1_score_
                
                external_best_pre_cond_l1SL[ct_outer,node] = cond_val_l1pr
                vol_best_pre_l1SL[ct_outer,node] = vol_
                
                size_clust_best_pre_l1SL[ct_outer,node] = size_clust_l1SL_
                true_positives_best_pre_l1SL[ct_outer,node] = true_positives_l1SL_
                precision_best_pre_l1SL[ct_outer,node] = precision
                recall_best_pre_l1SL[ct_outer,node] = recall
                f1score_best_pre_l1SL[ct_outer,node] = f1_score_
                
                cuts_best_pre_l1SL[ct_outer,node] = S
        
            if cond_val_l1pr <= min_conduct:
                
                min_conduct = cond_val_l1pr
                
                external_best_cond_l1SL[ct_outer,node] = cond_val_l1pr
                vol_best_cond_l1SL[ct_outer,node] = vol_
                
                size_clust_best_cond_l1SL[ct_outer,node] = size_clust_l1SL_
                true_positives_best_cond_l1SL[ct_outer,node] = true_positives_l1SL_
                precision_best_cond_l1SL[ct_outer,node] = precision
                recall_best_cond_l1SL[ct_outer,node] = recall
                f1score_best_cond_l1SL[ct_outer,node] = f1_score_
                
                cuts_best_cond_l1SL[ct_outer,node] = S

        print('outer:', ct_outer, 'number of node: ',node, ' completed: ', ct/how_many, ' degree: ', g.d[node])
        print('conductance: ', external_best_cond_l1SL[ct_outer,node], 'f1score: ', f1score_best_cond_l1SL[ct_outer,node], 'precision: ', precision_best_cond_l1SL[ct_outer,node], 'recall: ', recall_best_cond_l1SL[ct_outer,node])
        ct += 1
    end = time.time()
    print(" ")
    print("Outer: ", ct_outer," Elapsed time L1+SL with rounding: ", end - start)
    print("Outer: ", ct_outer," Number of experiments: ", number_experiments)
    print(" ")
    ct_outer += 1
# Out:
# 28
# outer: 0 number of node:  218  completed:  0.0  degree:  52.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  156  completed:  0.03571428571428571  degree:  79.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  215  completed:  0.07142857142857142  degree:  65.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  211  completed:  0.10714285714285714  degree:  63.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# /usr/local/Cellar/ipython/7.1.1/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:77: RuntimeWarning:
#
# divide by zero encountered in double_scalars
# outer: 0 number of node:  209  completed:  0.14285714285714285  degree:  63.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  196  completed:  0.17857142857142858  degree:  67.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  216  completed:  0.21428571428571427  degree:  72.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  195  completed:  0.25  degree:  76.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  186  completed:  0.2857142857142857  degree:  63.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  200  completed:  0.32142857142857145  degree:  45.0
# conductance:  0.4935930292157868 f1score:  0.9373638344226579 precision:  0.8821117375704767 recall:  1.0
# outer: 0 number of node:  198  completed:  0.35714285714285715  degree:  52.0
# conductance:  0.4329023629068212 f1score:  0.8683148335015136 precision:  0.7672759696834597 recall:  1.0
# outer: 0 number of node:  210  completed:  0.39285714285714285  degree:  63.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  204  completed:  0.42857142857142855  degree:  52.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  213  completed:  0.4642857142857143  degree:  63.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  203  completed:  0.5  degree:  53.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  212  completed:  0.5357142857142857  degree:  55.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  160  completed:  0.5714285714285714  degree:  66.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  217  completed:  0.6071428571428571  degree:  67.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  159  completed:  0.6428571428571429  degree:  65.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  208  completed:  0.6785714285714286  degree:  63.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  185  completed:  0.7142857142857143  degree:  63.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  206  completed:  0.75  degree:  62.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
# outer: 0 number of node:  214  completed:  0.7857142857142857  degree:  67.0
# conductance:  0.4460093896713615 f1score:  0.8937938197870683 precision:  0.807981220657277 recall:  1.0
# outer: 0 number of node:  201  completed:  0.8214285714285714  degree:  63.0
# conductance:  0.4411492122335496 f1score:  0.8873420984789894 precision:  0.7974976830398517 recall:  1.0
# outer: 0 number of node:  202  completed:  0.8571428571428571  degree:  54.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  205  completed:  0.8928571428571429  degree:  53.0
# conductance:  0.41677531508039983 f1score:  0.8557931377424167 precision:  0.74793568013907 recall:  1.0
# outer: 0 number of node:  197  completed:  0.9285714285714286  degree:  52.0
# conductance:  0.4329023629068212 f1score:  0.8683148335015136 precision:  0.7672759696834597 recall:  1.0
# outer: 0 number of node:  207  completed:  0.9642857142857143  degree:  63.0
# conductance:  0.4126234435379991 f1score:  0.8498765432098765 precision:  0.7389437526835552 recall:  1.0
#
# Outer:  0  Elapsed time L1+SL with rounding:  1.0683999061584473
# Outer:  0  Number of experiments:  112
#
# 100
# outer: 1 number of node:  89  completed:  0.0  degree:  149.0
# conductance:  0.42637759710930445 f1score:  0.8798687986879868 precision:  0.9000516195638146 recall:  0.8605712875562959
# outer: 1 number of node:  77  completed:  0.01  degree:  167.0
# conductance:  0.4256546826453617 f1score:  0.020395701025891548 precision:  1.0 recall:  0.01030291813190203
# outer: 1 number of node:  93  completed:  0.02  degree:  161.0
# conductance:  0.4126234435379991 f1score:  0.019670128283445325 precision:  1.0 recall:  0.00993275340860016
# outer: 1 number of node:  108  completed:  0.03  degree:  174.0
# conductance:  0.4126234435379991 f1score:  0.021241530855154733 precision:  1.0 recall:  0.01073477697575421
# outer: 1 number of node:  44  completed:  0.04  degree:  153.0
# conductance:  0.4333703679498072 f1score:  0.8851158362424628 precision:  0.9113783412848834 recall:  0.8603245110740947
# outer: 1 number of node:  117  completed:  0.05  degree:  163.0
# conductance:  0.448862897985705 f1score:  0.7879996202411468 precision:  0.8089668615984406 recall:  0.7680918008513788
# outer: 1 number of node:  132  completed:  0.06  degree:  162.0
# conductance:  0.4126234435379991 f1score:  0.019791094007696537 precision:  1.0 recall:  0.009994447529150472
# outer: 1 number of node:  17  completed:  0.07  degree:  164.0
# conductance:  0.44834270207404536 f1score:  0.8064760462033705 precision:  0.8255475867416165 recall:  0.7882657782713307
# outer: 1 number of node:  48  completed:  0.08  degree:  159.0
# conductance:  0.4126234435379991 f1score:  0.019428152492668622 precision:  1.0 recall:  0.009809365167499537
# outer: 1 number of node:  49  completed:  0.09  degree:  160.0
# conductance:  0.4126234435379991 f1score:  0.019549147779338995 precision:  1.0 recall:  0.00987105928804985
# outer: 1 number of node:  84  completed:  0.1  degree:  157.0
# conductance:  0.42488888888888887 f1score:  0.019186117560796776 precision:  1.0 recall:  0.009685976926398915
# outer: 1 number of node:  114  completed:  0.11  degree:  163.0
# conductance:  0.448862897985705 f1score:  0.7879996202411468 precision:  0.8089668615984406 recall:  0.7680918008513788
# outer: 1 number of node:  58  completed:  0.12  degree:  162.0
# conductance:  0.4457674539657753 f1score:  0.8191779086705935 precision:  0.8415641876504653 recall:  0.7979517551977297
# outer: 1 number of node:  46  completed:  0.13  degree:  161.0
# conductance:  0.4126234435379991 f1score:  0.019670128283445325 precision:  1.0 recall:  0.00993275340860016
# outer: 1 number of node:  45  completed:  0.14  degree:  159.0
# conductance:  0.4411492122335496 f1score:  0.019428152492668622 precision:  1.0 recall:  0.009809365167499537
# outer: 1 number of node:  105  completed:  0.15  degree:  148.0
# conductance:  0.4126234435379991 f1score:  0.018096227914654275 precision:  1.0 recall:  0.00913072984144611
# outer: 1 number of node:  52  completed:  0.16  degree:  159.0
# conductance:  0.4385259196781937 f1score:  0.8391626083106698 precision:  0.8608317653928502 recall:  0.8185575914615337
# outer: 1 number of node:  95  completed:  0.17  degree:  148.0
# conductance:  0.4126234435379991 f1score:  0.018096227914654275 precision:  1.0 recall:  0.00913072984144611
# outer: 1 number of node:  103  completed:  0.18  degree:  150.0
# conductance:  0.4126234435379991 f1score:  0.018338529249954154 precision:  1.0 recall:  0.009254118082546734
# outer: 1 number of node:  21  completed:  0.19  degree:  181.0
# conductance:  0.4950832315701523 f1score:  0.6804331402669352 precision:  0.6946461854874992 recall:  0.6667900549077673
# outer: 1 number of node:  126  completed:  0.2  degree:  167.0
# conductance:  0.46589072098286455 f1score:  0.7439540316979226 precision:  0.7618493372130618 recall:  0.7268801283237707
# outer: 1 number of node:  104  completed:  0.21  degree:  154.0
# conductance:  0.4256546826453617 f1score:  0.018822954225997682 precision:  1.0 recall:  0.00950089456474798
# outer: 1 number of node:  41  completed:  0.22  degree:  153.0
# conductance:  0.42921696468917436 f1score:  0.8691482649842271 precision:  0.8892905558065973 recall:  0.849898204701092
# outer: 1 number of node:  68  completed:  0.23  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.020274809160305347 precision:  1.0 recall:  0.010241224011351718
# outer: 1 number of node:  82  completed:  0.24  degree:  162.0
# conductance:  0.43960084033613445 f1score:  0.8438026780318693 precision:  0.8708639705882353 recall:  0.8183725090998828
# outer: 1 number of node:  75  completed:  0.25  degree:  167.0
# conductance:  0.4256546826453617 f1score:  0.020395701025891548 precision:  1.0 recall:  0.01030291813190203
# outer: 1 number of node:  112  completed:  0.26  degree:  164.0
# conductance:  0.4351006667961416 f1score:  0.8076825878190549 precision:  0.8276040655143394 recall:  0.7886976371151829
# outer: 1 number of node:  98  completed:  0.27  degree:  159.0
# conductance:  0.431287589730324 f1score:  0.8484465774185401 precision:  0.868912888831404 recall:  0.8289222037139861
# outer: 1 number of node:  57  completed:  0.28  degree:  162.0
# conductance:  0.4126234435379991 f1score:  0.019791094007696537 precision:  1.0 recall:  0.009994447529150472
# outer: 1 number of node:  90  completed:  0.29  degree:  161.0
# conductance:  0.4126234435379991 f1score:  0.019670128283445325 precision:  1.0 recall:  0.00993275340860016
# outer: 1 number of node:  63  completed:  0.3  degree:  165.0
# conductance:  0.4520778129645188 f1score:  0.7952780758790482 precision:  0.8141924642926388 recall:  0.777222530692825
# outer: 1 number of node:  118  completed:  0.31  degree:  175.0
# conductance:  0.4774380431284197 f1score:  0.7215851814516128 precision:  0.7372384937238494 recall:  0.7065827626627182
# outer: 1 number of node:  130  completed:  0.32  degree:  170.0
# conductance:  0.46773250146227335 f1score:  0.7566780605139891 precision:  0.7768895821147722 recall:  0.7374915170584243
# outer: 1 number of node:  76  completed:  0.33  degree:  155.0
# conductance:  0.4220264317180617 f1score:  0.018944023466145196 precision:  1.0 recall:  0.00956258868529829
# outer: 1 number of node:  115  completed:  0.34  degree:  171.0
# conductance:  0.46725770703203706 f1score:  0.7684738568396681 precision:  0.8025387870239774 recall:  0.7371830464556728
# outer: 1 number of node:  64  completed:  0.35  degree:  167.0
# conductance:  0.4256546826453617 f1score:  0.020395701025891548 precision:  1.0 recall:  0.01030291813190203
# outer: 1 number of node:  69  completed:  0.36  degree:  152.0
# conductance:  0.4126234435379991 f1score:  0.01858077134649471 precision:  1.0 recall:  0.009377506323647356
# outer: 1 number of node:  72  completed:  0.37  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.020274809160305347 precision:  1.0 recall:  0.010241224011351718
# outer: 1 number of node:  91  completed:  0.38  degree:  155.0
# conductance:  0.4268754076973255 f1score:  0.8955261739433718 precision:  0.9212002609262884 recall:  0.8712443704114998
# outer: 1 number of node:  92  completed:  0.39  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.020274809160305347 precision:  1.0 recall:  0.010241224011351718
# outer: 1 number of node:  107  completed:  0.4  degree:  161.0
# conductance:  0.4351588736760527 f1score:  0.8586123118669737 precision:  0.878713510720744 recall:  0.839410204207539
# outer: 1 number of node:  127  completed:  0.41  degree:  157.0
# conductance:  0.41677531508039983 f1score:  0.019186117560796776 precision:  1.0 recall:  0.009685976926398915
# outer: 1 number of node:  73  completed:  0.42  degree:  161.0
# conductance:  0.4383249886208466 f1score:  0.019670128283445325 precision:  1.0 recall:  0.00993275340860016
# outer: 1 number of node:  86  completed:  0.43  degree:  162.0
# conductance:  0.4126234435379991 f1score:  0.019791094007696537 precision:  1.0 recall:  0.009994447529150472
# outer: 1 number of node:  43  completed:  0.44  degree:  151.0
# conductance:  0.42756368386675375 f1score:  0.8956502427107458 precision:  0.9219464402351404 recall:  0.8708125115676476
# outer: 1 number of node:  88  completed:  0.45  degree:  161.0
# conductance:  0.4126234435379991 f1score:  0.019670128283445325 precision:  1.0 recall:  0.00993275340860016
# outer: 1 number of node:  28  completed:  0.46  degree:  166.0
# conductance:  0.4126234435379991 f1score:  0.020274809160305347 precision:  1.0 recall:  0.010241224011351718
# outer: 1 number of node:  70  completed:  0.47  degree:  169.0
# conductance:  0.4583523579675168 f1score:  0.7684844641724794 precision:  0.7904898571521753 recall:  0.7476710469492257
# outer: 1 number of node:  83  completed:  0.48  degree:  148.0
# conductance:  0.4126234435379991 f1score:  0.018096227914654275 precision:  1.0 recall:  0.00913072984144611
# outer: 1 number of node:  111  completed:  0.49  degree:  158.0
# conductance:  0.4449487744780184 f1score:  0.8072460560842212 precision:  0.8278433406821424 recall:  0.7876488370658277
# outer: 1 number of node:  79  completed:  0.5  degree:  155.0
# conductance:  0.4126234435379991 f1score:  0.018944023466145196 precision:  1.0 recall:  0.00956258868529829
# outer: 1 number of node:  31  completed:  0.51  degree:  166.0
# conductance:  0.4126234435379991 f1score:  0.020274809160305347 precision:  1.0 recall:  0.010241224011351718
# outer: 1 number of node:  50  completed:  0.52  degree:  171.0
# conductance:  0.4126234435379991 f1score:  0.020879120879120878 precision:  1.0 recall:  0.010549694614103275
# outer: 1 number of node:  99  completed:  0.53  degree:  157.0
# conductance:  0.42733441033925684 f1score:  0.8698396667087489 precision:  0.8904684975767366 recall:  0.8501449811832932
# outer: 1 number of node:  102  completed:  0.54  degree:  150.0
# conductance:  0.4126234435379991 f1score:  0.018338529249954154 precision:  1.0 recall:  0.009254118082546734
# outer: 1 number of node:  128  completed:  0.55  degree:  170.0
# conductance:  0.4411492122335496 f1score:  0.020758288051773613 precision:  1.0 recall:  0.010488000493552965
# outer: 1 number of node:  78  completed:  0.56  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.020274809160305347 precision:  1.0 recall:  0.010241224011351718
# outer: 1 number of node:  65  completed:  0.57  degree:  165.0
# conductance:  0.4520778129645188 f1score:  0.7952780758790482 precision:  0.8141924642926388 recall:  0.777222530692825
# outer: 1 number of node:  121  completed:  0.58  degree:  167.0
# conductance:  0.46589072098286455 f1score:  0.7439540316979226 precision:  0.7618493372130618 recall:  0.7268801283237707
# outer: 1 number of node:  125  completed:  0.59  degree:  168.0
# conductance:  0.46783016410523576 f1score:  0.7465230476793917 precision:  0.767257098202657 recall:  0.7268801283237707
# outer: 1 number of node:  106  completed:  0.6  degree:  160.0
# conductance:  0.4126234435379991 f1score:  0.019549147779338995 precision:  1.0 recall:  0.00987105928804985
# outer: 1 number of node:  87  completed:  0.61  degree:  157.0
# conductance:  0.42488888888888887 f1score:  0.019186117560796776 precision:  1.0 recall:  0.009685976926398915
# outer: 1 number of node:  124  completed:  0.62  degree:  172.0
# conductance:  0.4639308297844883 f1score:  0.7408872562870867 precision:  0.7543153049482163 recall:  0.7279289283731261
# outer: 1 number of node:  71  completed:  0.63  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.020274809160305347 precision:  1.0 recall:  0.010241224011351718
# outer: 1 number of node:  101  completed:  0.64  degree:  150.0
# conductance:  0.4126234435379991 f1score:  0.018338529249954154 precision:  1.0 recall:  0.009254118082546734
# outer: 1 number of node:  129  completed:  0.65  degree:  169.0
# conductance:  0.4411492122335496 f1score:  0.020637440468921724 precision:  1.0 recall:  0.010426306373002653
# outer: 1 number of node:  74  completed:  0.66  degree:  163.0
# conductance:  0.4411492122335496 f1score:  0.01991204495480088 precision:  1.0 recall:  0.010056141649700784
# outer: 1 number of node:  81  completed:  0.67  degree:  160.0
# conductance:  0.4420299284320104 f1score:  0.8401152664745559 precision:  0.8630448926480156 recall:  0.8183725090998828
# outer: 1 number of node:  123  completed:  0.68  degree:  172.0
# conductance:  0.4768488326594496 f1score:  0.7465364740195924 precision:  0.7678361810356071 recall:  0.7263865753593682
# outer: 1 number of node:  100  completed:  0.69  degree:  163.0
# conductance:  0.43623376623376625 f1score:  0.8503907115062166 precision:  0.8727272727272727 recall:  0.8291689801961873
# outer: 1 number of node:  53  completed:  0.7  degree:  179.0
# conductance:  0.4823670852257547 f1score:  0.734549886148616 precision:  0.7648944696767299 recall:  0.7065210685421679
# outer: 1 number of node:  62  completed:  0.71  degree:  160.0
# conductance:  0.4467534149025701 f1score:  0.8062294667677534 precision:  0.8261151032562957 recall:  0.7872786723425258
# outer: 1 number of node:  116  completed:  0.72  degree:  156.0
# conductance:  0.4318697710616772 f1score:  0.860629821676995 precision:  0.8826772164212984 recall:  0.8396569806897403
# outer: 1 number of node:  55  completed:  0.73  degree:  159.0
# conductance:  0.4126234435379991 f1score:  0.019428152492668622 precision:  1.0 recall:  0.009809365167499537
# outer: 1 number of node:  20  completed:  0.74  degree:  181.0
# conductance:  0.4951970851275257 f1score:  0.6691157679529771 precision:  0.6938058959920503 recall:  0.6461225245234129
# outer: 1 number of node:  61  completed:  0.75  degree:  155.0
# conductance:  0.4220264317180617 f1score:  0.018944023466145196 precision:  1.0 recall:  0.00956258868529829
# outer: 1 number of node:  109  completed:  0.76  degree:  174.0
# conductance:  0.4126234435379991 f1score:  0.021241530855154733 precision:  1.0 recall:  0.01073477697575421
# outer: 1 number of node:  40  completed:  0.77  degree:  153.0
# conductance:  0.42921696468917436 f1score:  0.8691482649842271 precision:  0.8892905558065973 recall:  0.849898204701092
# outer: 1 number of node:  122  completed:  0.78  degree:  166.0
# conductance:  0.46589072098286455 f1score:  0.7439540316979226 precision:  0.7618493372130618 recall:  0.7268801283237707
# outer: 1 number of node:  47  completed:  0.79  degree:  159.0
# conductance:  0.4126234435379991 f1score:  0.019428152492668622 precision:  1.0 recall:  0.009809365167499537
# outer: 1 number of node:  97  completed:  0.8  degree:  163.0
# conductance:  0.42488888888888887 f1score:  0.01991204495480088 precision:  1.0 recall:  0.010056141649700784
# outer: 1 number of node:  85  completed:  0.81  degree:  144.0
# conductance:  0.412263787119167 f1score:  0.9098750275443069 precision:  0.928911171101684 recall:  0.8916034301931026
# outer: 1 number of node:  96  completed:  0.82  degree:  168.0
# conductance:  0.4126234435379991 f1score:  0.020516578127862246 precision:  1.0 recall:  0.01036461225245234
# outer: 1 number of node:  60  completed:  0.83  degree:  147.0
# conductance:  0.42950349057219284 f1score:  0.8842592592592592 precision:  0.9097018333659554 recall:  0.860201122832994
# outer: 1 number of node:  94  completed:  0.84  degree:  167.0
# conductance:  0.4617280747275558 f1score:  0.7769169960474309 precision:  0.7968993253762325 recall:  0.7579122709605774
# outer: 1 number of node:  113  completed:  0.85  degree:  163.0
# conductance:  0.448862897985705 f1score:  0.7879996202411468 precision:  0.8089668615984406 recall:  0.7680918008513788
# outer: 1 number of node:  120  completed:  0.86  degree:  167.0
# conductance:  0.46589072098286455 f1score:  0.7439540316979226 precision:  0.7618493372130618 recall:  0.7268801283237707
# outer: 1 number of node:  133  completed:  0.87  degree:  170.0
# conductance:  0.47087857847976305 f1score:  0.020758288051773613 precision:  1.0 recall:  0.010488000493552965
# outer: 1 number of node:  80  completed:  0.88  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.020274809160305347 precision:  1.0 recall:  0.010241224011351718
# outer: 1 number of node:  66  completed:  0.89  degree:  155.0
# conductance:  0.4220264317180617 f1score:  0.018944023466145196 precision:  1.0 recall:  0.00956258868529829
# outer: 1 number of node:  56  completed:  0.9  degree:  159.0
# conductance:  0.4305582383619857 f1score:  0.8584120982986768 precision:  0.8771489279505505 recall:  0.8404590042568943
# outer: 1 number of node:  15  completed:  0.91  degree:  166.0
# conductance:  0.4471404958677686 f1score:  0.8253015893278866 precision:  0.8548760330578512 recall:  0.7977049787155284
# outer: 1 number of node:  51  completed:  0.92  degree:  157.0
# conductance:  0.4126234435379991 f1score:  0.019186117560796776 precision:  1.0 recall:  0.009685976926398915
# outer: 1 number of node:  110  completed:  0.93  degree:  167.0
# conductance:  0.41677531508039983 f1score:  0.020395701025891548 precision:  1.0 recall:  0.01030291813190203
# outer: 1 number of node:  59  completed:  0.94  degree:  169.0
# conductance:  0.4728268126585659 f1score:  0.7871869689293616 precision:  0.819535318467085 recall:  0.7572953297550743
# outer: 1 number of node:  42  completed:  0.95  degree:  155.0
# conductance:  0.43475724379334935 f1score:  0.8494752813250727 precision:  0.8710053801776106 recall:  0.8289838978345364
# outer: 1 number of node:  131  completed:  0.96  degree:  168.0
# conductance:  0.4411492122335496 f1score:  0.020516578127862246 precision:  1.0 recall:  0.01036461225245234
# outer: 1 number of node:  119  completed:  0.97  degree:  178.0
# conductance:  0.47722823959284877 f1score:  0.7482479784366576 precision:  0.7698029492365914 recall:  0.7278672342525757
# outer: 1 number of node:  67  completed:  0.98  degree:  166.0
# conductance:  0.4411492122335496 f1score:  0.020274809160305347 precision:  1.0 recall:  0.010241224011351718
# outer: 1 number of node:  54  completed:  0.99  degree:  154.0
# conductance:  0.4126234435379991 f1score:  0.018822954225997682 precision:  1.0 recall:  0.00950089456474798
#
# Outer:  1  Elapsed time L1+SL with rounding:  97.01597905158997
# Outer:  1  Number of experiments:  512

# %% [markdown]
# ## Performance of l1+SL

# %%
all_data = []
xlabels_ = []

print('Results for L1+SL')
sum_precision = 0
sum_recall = 0
sum_f1 = 0
sum_conductance = 0

info_ref_nodes = all_clusters
l_info_ref_nodes = len(info_ref_nodes)

for i in range(l_info_ref_nodes):
    temp_pre = []
    temp_rec = []
    temp_f1 = []
    temp_conductance = []
    
    for j in all_clusters[i]:
        temp_pre.append(precision_best_cond_l1SL[i,j])
        temp_rec.append(recall_best_cond_l1SL[i,j])
        temp_f1.append(f1score_best_cond_l1SL[i,j])
        temp_conductance.append(external_best_cond_l1SL[i,j])

    print('Feature:', i,'Precision', stat_.mean(temp_pre), 'Recall', stat_.mean(temp_rec), 'F1', stat_.mean(temp_f1), 'Cond.', stat_.mean(temp_conductance))
# Out:
# Results for L1+SL
# Feature: 0 Precision 0.7683214659749378 Recall 1.0 F1 0.8685372472776756 Cond. 0.427663502821075
# Feature: 1 Precision 0.9205054772869868 Recall 0.3664982417175643 F1 0.381185986391101 Cond. 0.4354129237780968
